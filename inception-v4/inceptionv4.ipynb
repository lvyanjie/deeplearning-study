# %% [markdown]
# ## 算法介绍
#
#   inception v4提出背景：He KaiMing 认为 residual connection 在训练很深的卷积网络模型是很有必要的，由此，作者考虑如果只采用 inception 结构，能否训练一个很深的网络，因此提出inception v4。
#
#   下面是 Inception V4 的网络架构，其中，左图是网络的整体结构，右图是网络中Stem的详细结构。
#
#   ![fig1](fig1.png)
#
#   框架中涉及的几种inception module结构，下图从左到右依次是Inception-A、Inception-B、Inception-C
#
#   ![fig2](fig2.png)
#
#   下图从左到右分别是Reduction-A， Reduction-B
#
#   ![fig3](fig3.png)

# %% [markdown]
# ## 算法实现

# %% [markdown]
# 下面我们基于上述结构构建inception-v4模型：

# %%
import keras

#conv_layer
def conv_layer(x, filters, kernel_size, padding = 'same', strides = (1, 1),name = None):
    '''
    conv + bn + relu
    :param x: tensor, tensor of previous layer
    :param filters: integer, number of kernel
    :param kernel_size: tumple, kernel's (row, col)
    :param padding: 'same' or 'valid'
    :param strides: tumple, stride of kernel
    :param name: layer's name
    
    returns:
    output tensor
    '''
    x = keras.layers.Conv2D(filters, kernel_size, strides = strides, padding = padding, use_bias = False, name = name + '_conv')(x)
    x = keras.layers.BatchNormalization(axis = 3, name = name + '_bn')(x)
    x = keras.layers.Activation('relu', name = name + '_relu')(x)
    
    return x
# Out:
# Using TensorFlow backend.

# %%
def inceptionA(x, name = None):
    '''
    inceptionA
    :param x: input tensor
    :param name: string
    
    returns:
    output tensor
    '''
    #branch0
    branch0 = conv_layer(x = x, filters = 64, kernel_size = (1, 1), name = name + '_branch0_conv1x1')
    branch0 = conv_layer(x = branch0, filters = 96, kernel_size = (3, 3), name = name + '_branch0_conv3x3_1')
    branch0 = conv_layer(x = branch0, filters = 96, kernel_size = (3, 3), name = name + '_branch0_conv3x3_2')
    
    #branch1
    branch1 = conv_layer(x = x, filters = 64, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    branch1 = conv_layer(x = branch1, filters = 96, kernel_size = (3, 3), name = name + '_branch1_conv3x3')
    
    #branch2
    branch2 = conv_layer(x = x, filters = 96, kernel_size = (1, 1), name = name + '_branch2_conv1x1')
    
    #branch3
    branch3 = keras.layers.AveragePooling2D(pool_size = (3, 3), strides = (1, 1),padding = 'same', name = name + '_branch3_pool')(x)
    branch3 = conv_layer(x = branch3, filters = 96, kernel_size = (1, 1), name = name + '_branch3_conv1x1')
    
    x = keras.layers.Concatenate(axis = 3, name = name + '_concat')([branch0, branch1, branch2, branch3])
    return x

# %%
def inceptionB(x, name = None):
    '''
    inceptionB
    :param x: input tensor
    :param name: string
    
    returns:
    output tensor
    '''
    #branch0
    branch0 = conv_layer(x = x, filters = 192, kernel_size = (1, 1), name = name + '_branch0_conv1x1')
    branch0 = conv_layer(x = branch0, filters = 192, kernel_size = (1, 7), name = name + '_branch0_1x7_1')
    branch0 = conv_layer(x = branch0, filters = 224, kernel_size = (7, 1), name = name + '_branch0_7x1_1')
    branch0 = conv_layer(x = branch0, filters = 224, kernel_size = (1, 7), name = name + '_branch0_1x7_2')
    branch0 = conv_layer(x = branch0, filters = 256, kernel_size = (7, 1), name = name + '_branch0_7x1_2')
    
    #branch1
    branch1 = conv_layer(x = x, filters = 192, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    branch1 = conv_layer(x = branch1, filters = 224, kernel_size = (7, 1), name = name + '_branch1_conv7x7_1')
    branch1 = conv_layer(x = branch1, filters = 256, kernel_size = (1, 7), name = name + '_branch1_conv7x7_2')
    
    #branch2
    branch2 = conv_layer(x = x, filters = 384, kernel_size = (1, 1), name = name + '_branch2_conv1x1')
    
    #branch3
    branch3 = keras.layers.AveragePooling2D(pool_size = (3, 3), strides = (1, 1), padding = 'same', name = name + '_branch3_pool')(x)
    branch3 = conv_layer(x = branch3, filters = 128, kernel_size = (1, 1), name = name + '_branch3_conv1x1')
    
    x = keras.layers.Concatenate(axis = 3, name = name + '_concat')([branch0, branch1, branch2, branch3])
    return x

# %%
def inceptionC(x, name = None):
    '''
    inceptionC
    :param x: input tensor
    :param name: string
    
    returns:
    output tensor
    '''
    #branch0
    branch0 = conv_layer(x = x, filters = 384, kernel_size = (1, 1), name = name + '_branch0_conv1x1')
    branch0 = conv_layer(x = branch0, filters = 448, kernel_size = (1, 3), name = name + '_branch0_conv1x3')
    branch0 = conv_layer(x = branch0, filters = 512, kernel_size = (3, 1), name = name + '_branch0_conv3x1')
    branch0_r = conv_layer(x = branch0, filters = 256, kernel_size = (1, 3), name = name + '_branch0_conv1x3_r')
    branch0_l = conv_layer(x = branch0, filters = 256, kernel_size = (3, 1), name = name + '_branch0_conv3x1_l')
    branch0 = keras.layers.Concatenate(axis =3, name = name + '_branch0_concat')([branch0_r, branch0_l])
    
    #branch1
    branch1 = conv_layer(x = x, filters = 384, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    branch1_l = conv_layer(x = branch1, filters = 256, kernel_size = (1, 3), name = name + '_branch1_conv1x3_l')
    branch1_r = conv_layer(x = branch1, filters = 256, kernel_size = (3, 1), name = name + '_branch1_conv3x1_r')
    branch1 = keras.layers.Concatenate(axis = 3, name = name + '_branch1_concat')([branch1_l, branch1_r])
    
    #branch2
    branch2 = conv_layer(x = x, filters = 256, kernel_size = (1, 1), name = name + '_branch2_conv1x1')
    
    #branch3
    branch3 = keras.layers.AveragePooling2D(pool_size = (3, 3), strides = (1, 1), padding = 'same', name = name + '_branch3_pool')(x)
    branch3 = conv_layer(x = branch3, filters = 256, kernel_size = (1, 1), name = name + '_branch3_conv1x1')
    
    x = keras.layers.Concatenate(axis = 3, name = name + '_concat')([branch0, branch1, branch2, branch3])
    return x

# %%
def reductionA(x, name = None):
    '''
    reduction A
    :param x: input tensor
    :param name: string
    
    returns:
    output tensor
    '''
    #branch0
    branch0 = conv_layer(x = x, filters = 384, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = name + '_branch0_conv3x3')
    
    #branch1
    branch1 = conv_layer(x = x, filters = 192, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    branch1 = conv_layer(x = branch1, filters = 224, kernel_size = (3, 3), name = name + '_branch1_conv3x3_1')
    branch1 = conv_layer(x = branch1, filters = 256, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = name + '_branch1_conv3x3_2')
    
    #branch3
    branch2 = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'valid', name = name + '_branch2_pool')(x)
    
    x = keras.layers.Concatenate(axis = 3, name = name + '_concat')([branch0, branch1, branch2])
    return x

# %%
def reductionB(x, name = None):
    '''
    reduction B
    :param x: input tensor
    :param name: string
    
    returns:
    output tensor
    '''
    #branch0
    branch0 = conv_layer(x = x, filters = 192, kernel_size = (1, 1), name = name + '_branch0_conv1x1')
    branch0 = conv_layer(x = branch0, filters = 192, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = name + '_branch0_conv3x3')
    
    #branch1
    branch1 = conv_layer(x = x, filters = 256, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    branch1 = conv_layer(x = branch1, filters = 256, kernel_size = (1, 7), name = name + '_branch1_conv7x7_1')
    branch1 = conv_layer(x = branch1, filters = 320, kernel_size = (7, 1), name = name + '_branch1_conv7x7_2')
    branch1 = conv_layer(x = branch1, filters = 320, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = name + '_branch1_conv3x3')
    
    #branch2
    branch2 = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'valid', name = name + '_branch2_pool')(x)
    
    x = keras.layers.Concatenate(axis = 3, name = name + '_concat')([branch0, branch1, branch2])
    return x

# %%
def InceptionV4(input_shape = (299, 299, 3), classes = 1000, use_dropout = True, dropout_rate = 0.2):
    '''
    Inception V4
    :param input_shape: tumple, input shape of network
    :param classes: integer, number of class of network
    :param use_dropout: bool, use dropout or not
    :param dropout_rate: float, only valid if use_dropout is True
    
    returns:
    keras model
    '''
    #stem
    x_input = keras.layers.Input(input_shape)
    
    x = conv_layer(x = x_input, filters = 32, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = 'stem_block0_conv0')#149,149,32
    x = conv_layer(x = x, filters = 32, kernel_size = (3, 3), padding = 'valid', name = 'stem_block0_conv1')#147,147,32
    x = conv_layer(x = x, filters = 64, kernel_size = (3, 3), name = 'stem_block0_conv2')#147,147,64
    
    branch0 = conv_layer(x = x, filters = 96, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = 'stem_block0_branch0')
    branch1 = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'valid', name = 'stem_block0_branch1')(x)
    
    x = keras.layers.Concatenate(axis = 3, name = 'stem_block0_concat')([branch0, branch1])# 73, 73 160
    
    branch0 = conv_layer(x = x, filters = 64, kernel_size = (1, 1), name = 'stem_block1_branch0_conv0')
    branch0 = conv_layer(x = branch0, filters = 64, kernel_size = (7, 1), name = 'stem_block1_branch0_conv1')
    branch0 = conv_layer(x = branch0, filters = 64, kernel_size = (1, 7), name = 'stem_block1_branch0_conv2')
    branch0 = conv_layer(x = branch0, filters = 96, kernel_size = (3, 3), padding = 'valid', name = 'stem_block1_branch0_conv3')
    
    branch1 = conv_layer(x = x, filters = 64, kernel_size = (1, 1), name = 'stem_block1_branch1_conv0')
    branch1 = conv_layer(x = branch1, filters = 96, kernel_size = (3, 3), padding = 'valid', name = 'stem_block1_branch1_conv1')
    
    x = keras.layers.Concatenate(axis = 3, name = 'stem_block1_concat')([branch0, branch1])
    
    branch0 = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'valid', name = 'stem_block2_branch0')(x)
    branch1 = conv_layer(x = x, filters = 192, kernel_size = (3, 3), strides = (2, 2), padding = 'valid', name = 'stem_block2_branch1')

    x = keras.layers.Concatenate(axis = 3, name = 'stem_block2_concat')([branch0, branch1])
    
    #4xinception-A
    for i in range(4):
        x = inceptionA(x = x, name = 'InceptionA'+str(i))
        
    #reductionA
    x = reductionA(x, name = 'ReductionA')
    
    #7xinception-B
    for i in range(7):
        x = inceptionB(x, name = 'InceptionB'+str(i))
    
    #reductionB
    x = reductionB(x, name = 'ReductionB')
    
    #3xinception-C
    for i in range(3):
        x = inceptionC(x, name = 'InceptionC'+str(i))
    
    x = keras.layers.GlobalAveragePooling2D(name = 'globalaveragepooling')(x)
    if use_dropout:
        x = keras.layers.Dropout(dropout_rate)(x)
    x = keras.layers.Dense(classes, activation = 'softmax', name = 'classificaiton')(x)
    
    model = keras.models.Model(inputs = x_input, outputs = x, name = 'inceptionv4')
    return model

# %%
model = InceptionV4()
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# stem_block0_conv0_conv (Conv2D) (None, 149, 149, 32) 864         input_4[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv0_bn (BatchNorm (None, 149, 149, 32) 128         stem_block0_conv0_conv[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv0_relu (Activat (None, 149, 149, 32) 0           stem_block0_conv0_bn[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv1_conv (Conv2D) (None, 147, 147, 32) 9216        stem_block0_conv0_relu[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv1_bn (BatchNorm (None, 147, 147, 32) 128         stem_block0_conv1_conv[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv1_relu (Activat (None, 147, 147, 32) 0           stem_block0_conv1_bn[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv2_conv (Conv2D) (None, 147, 147, 64) 18432       stem_block0_conv1_relu[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv2_bn (BatchNorm (None, 147, 147, 64) 256         stem_block0_conv2_conv[0][0]
# __________________________________________________________________________________________________
# stem_block0_conv2_relu (Activat (None, 147, 147, 64) 0           stem_block0_conv2_bn[0][0]
# __________________________________________________________________________________________________
# stem_block0_branch0_conv (Conv2 (None, 73, 73, 96)   55296       stem_block0_conv2_relu[0][0]
# __________________________________________________________________________________________________
# stem_block0_branch0_bn (BatchNo (None, 73, 73, 96)   384         stem_block0_branch0_conv[0][0]
# __________________________________________________________________________________________________
# stem_block0_branch0_relu (Activ (None, 73, 73, 96)   0           stem_block0_branch0_bn[0][0]
# __________________________________________________________________________________________________
# stem_block0_branch1 (MaxPooling (None, 73, 73, 64)   0           stem_block0_conv2_relu[0][0]
# __________________________________________________________________________________________________
# stem_block0_concat (Concatenate (None, 73, 73, 160)  0           stem_block0_branch0_relu[0][0]
#                                                                  stem_block0_branch1[0][0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv0_conv  (None, 73, 73, 64)   10240       stem_block0_concat[0][0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv0_bn (B (None, 73, 73, 64)   256         stem_block1_branch0_conv0_conv[0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv0_relu  (None, 73, 73, 64)   0           stem_block1_branch0_conv0_bn[0][0
# __________________________________________________________________________________________________
# stem_block1_branch0_conv1_conv  (None, 73, 73, 64)   28672       stem_block1_branch0_conv0_relu[0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv1_bn (B (None, 73, 73, 64)   256         stem_block1_branch0_conv1_conv[0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv1_relu  (None, 73, 73, 64)   0           stem_block1_branch0_conv1_bn[0][0
# __________________________________________________________________________________________________
# stem_block1_branch0_conv2_conv  (None, 73, 73, 64)   28672       stem_block1_branch0_conv1_relu[0]
# __________________________________________________________________________________________________
# stem_block1_branch1_conv0_conv  (None, 73, 73, 64)   10240       stem_block0_concat[0][0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv2_bn (B (None, 73, 73, 64)   256         stem_block1_branch0_conv2_conv[0]
# __________________________________________________________________________________________________
# stem_block1_branch1_conv0_bn (B (None, 73, 73, 64)   256         stem_block1_branch1_conv0_conv[0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv2_relu  (None, 73, 73, 64)   0           stem_block1_branch0_conv2_bn[0][0
# __________________________________________________________________________________________________
# stem_block1_branch1_conv0_relu  (None, 73, 73, 64)   0           stem_block1_branch1_conv0_bn[0][0
# __________________________________________________________________________________________________
# stem_block1_branch0_conv3_conv  (None, 71, 71, 96)   55296       stem_block1_branch0_conv2_relu[0]
# __________________________________________________________________________________________________
# stem_block1_branch1_conv1_conv  (None, 71, 71, 96)   55296       stem_block1_branch1_conv0_relu[0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv3_bn (B (None, 71, 71, 96)   384         stem_block1_branch0_conv3_conv[0]
# __________________________________________________________________________________________________
# stem_block1_branch1_conv1_bn (B (None, 71, 71, 96)   384         stem_block1_branch1_conv1_conv[0]
# __________________________________________________________________________________________________
# stem_block1_branch0_conv3_relu  (None, 71, 71, 96)   0           stem_block1_branch0_conv3_bn[0][0
# __________________________________________________________________________________________________
# stem_block1_branch1_conv1_relu  (None, 71, 71, 96)   0           stem_block1_branch1_conv1_bn[0][0
# __________________________________________________________________________________________________
# stem_block1_concat (Concatenate (None, 71, 71, 192)  0           stem_block1_branch0_conv3_relu[0]
#                                                                  stem_block1_branch1_conv1_relu[0]
# __________________________________________________________________________________________________
# stem_block2_branch1_conv (Conv2 (None, 35, 35, 192)  331776      stem_block1_concat[0][0]
# __________________________________________________________________________________________________
# stem_block2_branch1_bn (BatchNo (None, 35, 35, 192)  768         stem_block2_branch1_conv[0][0]
# __________________________________________________________________________________________________
# stem_block2_branch0 (MaxPooling (None, 35, 35, 192)  0           stem_block1_concat[0][0]
# __________________________________________________________________________________________________
# stem_block2_branch1_relu (Activ (None, 35, 35, 192)  0           stem_block2_branch1_bn[0][0]
# __________________________________________________________________________________________________
# stem_block2_concat (Concatenate (None, 35, 35, 384)  0           stem_block2_branch0[0][0]
#                                                                  stem_block2_branch1_relu[0][0]
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv1x1_con (None, 35, 35, 64)   24576       stem_block2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA0_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv1x1_rel (None, 35, 35, 64)   0           InceptionA0_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv3x3_1_c (None, 35, 35, 96)   55296       InceptionA0_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA0_branch1_conv1x1_con (None, 35, 35, 64)   24576       stem_block2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv3x3_1_b (None, 35, 35, 96)   384         InceptionA0_branch0_conv3x3_1_con
# __________________________________________________________________________________________________
# InceptionA0_branch1_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA0_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv3x3_1_r (None, 35, 35, 96)   0           InceptionA0_branch0_conv3x3_1_bn[
# __________________________________________________________________________________________________
# InceptionA0_branch1_conv1x1_rel (None, 35, 35, 64)   0           InceptionA0_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA0_branch3_pool (Avera (None, 35, 35, 384)  0           stem_block2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv3x3_2_c (None, 35, 35, 96)   82944       InceptionA0_branch0_conv3x3_1_rel
# __________________________________________________________________________________________________
# InceptionA0_branch1_conv3x3_con (None, 35, 35, 96)   55296       InceptionA0_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA0_branch2_conv1x1_con (None, 35, 35, 96)   36864       stem_block2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA0_branch3_conv1x1_con (None, 35, 35, 96)   36864       InceptionA0_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv3x3_2_b (None, 35, 35, 96)   384         InceptionA0_branch0_conv3x3_2_con
# __________________________________________________________________________________________________
# InceptionA0_branch1_conv3x3_bn  (None, 35, 35, 96)   384         InceptionA0_branch1_conv3x3_conv[
# __________________________________________________________________________________________________
# InceptionA0_branch2_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA0_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA0_branch3_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA0_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA0_branch0_conv3x3_2_r (None, 35, 35, 96)   0           InceptionA0_branch0_conv3x3_2_bn[
# __________________________________________________________________________________________________
# InceptionA0_branch1_conv3x3_rel (None, 35, 35, 96)   0           InceptionA0_branch1_conv3x3_bn[0]
# __________________________________________________________________________________________________
# InceptionA0_branch2_conv1x1_rel (None, 35, 35, 96)   0           InceptionA0_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA0_branch3_conv1x1_rel (None, 35, 35, 96)   0           InceptionA0_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA0_concat (Concatenate (None, 35, 35, 384)  0           InceptionA0_branch0_conv3x3_2_rel
#                                                                  InceptionA0_branch1_conv3x3_relu[
#                                                                  InceptionA0_branch2_conv1x1_relu[
#                                                                  InceptionA0_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv1x1_con (None, 35, 35, 64)   24576       InceptionA0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA1_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv1x1_rel (None, 35, 35, 64)   0           InceptionA1_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv3x3_1_c (None, 35, 35, 96)   55296       InceptionA1_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA1_branch1_conv1x1_con (None, 35, 35, 64)   24576       InceptionA0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv3x3_1_b (None, 35, 35, 96)   384         InceptionA1_branch0_conv3x3_1_con
# __________________________________________________________________________________________________
# InceptionA1_branch1_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA1_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv3x3_1_r (None, 35, 35, 96)   0           InceptionA1_branch0_conv3x3_1_bn[
# __________________________________________________________________________________________________
# InceptionA1_branch1_conv1x1_rel (None, 35, 35, 64)   0           InceptionA1_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA1_branch3_pool (Avera (None, 35, 35, 384)  0           InceptionA0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv3x3_2_c (None, 35, 35, 96)   82944       InceptionA1_branch0_conv3x3_1_rel
# __________________________________________________________________________________________________
# InceptionA1_branch1_conv3x3_con (None, 35, 35, 96)   55296       InceptionA1_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA1_branch2_conv1x1_con (None, 35, 35, 96)   36864       InceptionA0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA1_branch3_conv1x1_con (None, 35, 35, 96)   36864       InceptionA1_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv3x3_2_b (None, 35, 35, 96)   384         InceptionA1_branch0_conv3x3_2_con
# __________________________________________________________________________________________________
# InceptionA1_branch1_conv3x3_bn  (None, 35, 35, 96)   384         InceptionA1_branch1_conv3x3_conv[
# __________________________________________________________________________________________________
# InceptionA1_branch2_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA1_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA1_branch3_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA1_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA1_branch0_conv3x3_2_r (None, 35, 35, 96)   0           InceptionA1_branch0_conv3x3_2_bn[
# __________________________________________________________________________________________________
# InceptionA1_branch1_conv3x3_rel (None, 35, 35, 96)   0           InceptionA1_branch1_conv3x3_bn[0]
# __________________________________________________________________________________________________
# InceptionA1_branch2_conv1x1_rel (None, 35, 35, 96)   0           InceptionA1_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA1_branch3_conv1x1_rel (None, 35, 35, 96)   0           InceptionA1_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA1_concat (Concatenate (None, 35, 35, 384)  0           InceptionA1_branch0_conv3x3_2_rel
#                                                                  InceptionA1_branch1_conv3x3_relu[
#                                                                  InceptionA1_branch2_conv1x1_relu[
#                                                                  InceptionA1_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv1x1_con (None, 35, 35, 64)   24576       InceptionA1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA2_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv1x1_rel (None, 35, 35, 64)   0           InceptionA2_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv3x3_1_c (None, 35, 35, 96)   55296       InceptionA2_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA2_branch1_conv1x1_con (None, 35, 35, 64)   24576       InceptionA1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv3x3_1_b (None, 35, 35, 96)   384         InceptionA2_branch0_conv3x3_1_con
# __________________________________________________________________________________________________
# InceptionA2_branch1_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA2_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv3x3_1_r (None, 35, 35, 96)   0           InceptionA2_branch0_conv3x3_1_bn[
# __________________________________________________________________________________________________
# InceptionA2_branch1_conv1x1_rel (None, 35, 35, 64)   0           InceptionA2_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA2_branch3_pool (Avera (None, 35, 35, 384)  0           InceptionA1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv3x3_2_c (None, 35, 35, 96)   82944       InceptionA2_branch0_conv3x3_1_rel
# __________________________________________________________________________________________________
# InceptionA2_branch1_conv3x3_con (None, 35, 35, 96)   55296       InceptionA2_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA2_branch2_conv1x1_con (None, 35, 35, 96)   36864       InceptionA1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA2_branch3_conv1x1_con (None, 35, 35, 96)   36864       InceptionA2_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv3x3_2_b (None, 35, 35, 96)   384         InceptionA2_branch0_conv3x3_2_con
# __________________________________________________________________________________________________
# InceptionA2_branch1_conv3x3_bn  (None, 35, 35, 96)   384         InceptionA2_branch1_conv3x3_conv[
# __________________________________________________________________________________________________
# InceptionA2_branch2_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA2_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA2_branch3_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA2_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA2_branch0_conv3x3_2_r (None, 35, 35, 96)   0           InceptionA2_branch0_conv3x3_2_bn[
# __________________________________________________________________________________________________
# InceptionA2_branch1_conv3x3_rel (None, 35, 35, 96)   0           InceptionA2_branch1_conv3x3_bn[0]
# __________________________________________________________________________________________________
# InceptionA2_branch2_conv1x1_rel (None, 35, 35, 96)   0           InceptionA2_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA2_branch3_conv1x1_rel (None, 35, 35, 96)   0           InceptionA2_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA2_concat (Concatenate (None, 35, 35, 384)  0           InceptionA2_branch0_conv3x3_2_rel
#                                                                  InceptionA2_branch1_conv3x3_relu[
#                                                                  InceptionA2_branch2_conv1x1_relu[
#                                                                  InceptionA2_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv1x1_con (None, 35, 35, 64)   24576       InceptionA2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA3_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv1x1_rel (None, 35, 35, 64)   0           InceptionA3_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv3x3_1_c (None, 35, 35, 96)   55296       InceptionA3_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA3_branch1_conv1x1_con (None, 35, 35, 64)   24576       InceptionA2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv3x3_1_b (None, 35, 35, 96)   384         InceptionA3_branch0_conv3x3_1_con
# __________________________________________________________________________________________________
# InceptionA3_branch1_conv1x1_bn  (None, 35, 35, 64)   256         InceptionA3_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv3x3_1_r (None, 35, 35, 96)   0           InceptionA3_branch0_conv3x3_1_bn[
# __________________________________________________________________________________________________
# InceptionA3_branch1_conv1x1_rel (None, 35, 35, 64)   0           InceptionA3_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA3_branch3_pool (Avera (None, 35, 35, 384)  0           InceptionA2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv3x3_2_c (None, 35, 35, 96)   82944       InceptionA3_branch0_conv3x3_1_rel
# __________________________________________________________________________________________________
# InceptionA3_branch1_conv3x3_con (None, 35, 35, 96)   55296       InceptionA3_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionA3_branch2_conv1x1_con (None, 35, 35, 96)   36864       InceptionA2_concat[0][0]
# __________________________________________________________________________________________________
# InceptionA3_branch3_conv1x1_con (None, 35, 35, 96)   36864       InceptionA3_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv3x3_2_b (None, 35, 35, 96)   384         InceptionA3_branch0_conv3x3_2_con
# __________________________________________________________________________________________________
# InceptionA3_branch1_conv3x3_bn  (None, 35, 35, 96)   384         InceptionA3_branch1_conv3x3_conv[
# __________________________________________________________________________________________________
# InceptionA3_branch2_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA3_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA3_branch3_conv1x1_bn  (None, 35, 35, 96)   384         InceptionA3_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionA3_branch0_conv3x3_2_r (None, 35, 35, 96)   0           InceptionA3_branch0_conv3x3_2_bn[
# __________________________________________________________________________________________________
# InceptionA3_branch1_conv3x3_rel (None, 35, 35, 96)   0           InceptionA3_branch1_conv3x3_bn[0]
# __________________________________________________________________________________________________
# InceptionA3_branch2_conv1x1_rel (None, 35, 35, 96)   0           InceptionA3_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA3_branch3_conv1x1_rel (None, 35, 35, 96)   0           InceptionA3_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionA3_concat (Concatenate (None, 35, 35, 384)  0           InceptionA3_branch0_conv3x3_2_rel
#                                                                  InceptionA3_branch1_conv3x3_relu[
#                                                                  InceptionA3_branch2_conv1x1_relu[
#                                                                  InceptionA3_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# ReductionA_branch1_conv1x1_conv (None, 35, 35, 192)  73728       InceptionA3_concat[0][0]
# __________________________________________________________________________________________________
# ReductionA_branch1_conv1x1_bn ( (None, 35, 35, 192)  768         ReductionA_branch1_conv1x1_conv[0
# __________________________________________________________________________________________________
# ReductionA_branch1_conv1x1_relu (None, 35, 35, 192)  0           ReductionA_branch1_conv1x1_bn[0][
# __________________________________________________________________________________________________
# ReductionA_branch1_conv3x3_1_co (None, 35, 35, 224)  387072      ReductionA_branch1_conv1x1_relu[0
# __________________________________________________________________________________________________
# ReductionA_branch1_conv3x3_1_bn (None, 35, 35, 224)  896         ReductionA_branch1_conv3x3_1_conv
# __________________________________________________________________________________________________
# ReductionA_branch1_conv3x3_1_re (None, 35, 35, 224)  0           ReductionA_branch1_conv3x3_1_bn[0
# __________________________________________________________________________________________________
# ReductionA_branch0_conv3x3_conv (None, 17, 17, 384)  1327104     InceptionA3_concat[0][0]
# __________________________________________________________________________________________________
# ReductionA_branch1_conv3x3_2_co (None, 17, 17, 256)  516096      ReductionA_branch1_conv3x3_1_relu
# __________________________________________________________________________________________________
# ReductionA_branch0_conv3x3_bn ( (None, 17, 17, 384)  1536        ReductionA_branch0_conv3x3_conv[0
# __________________________________________________________________________________________________
# ReductionA_branch1_conv3x3_2_bn (None, 17, 17, 256)  1024        ReductionA_branch1_conv3x3_2_conv
# __________________________________________________________________________________________________
# ReductionA_branch0_conv3x3_relu (None, 17, 17, 384)  0           ReductionA_branch0_conv3x3_bn[0][
# __________________________________________________________________________________________________
# ReductionA_branch1_conv3x3_2_re (None, 17, 17, 256)  0           ReductionA_branch1_conv3x3_2_bn[0
# __________________________________________________________________________________________________
# ReductionA_branch2_pool (MaxPoo (None, 17, 17, 384)  0           InceptionA3_concat[0][0]
# __________________________________________________________________________________________________
# ReductionA_concat (Concatenate) (None, 17, 17, 1024) 0           ReductionA_branch0_conv3x3_relu[0
#                                                                  ReductionA_branch1_conv3x3_2_relu
#                                                                  ReductionA_branch2_pool[0][0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_conv1x1_con (None, 17, 17, 192)  196608      ReductionA_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_conv1x1_bn  (None, 17, 17, 192)  768         InceptionB0_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB0_branch0_conv1x1_rel (None, 17, 17, 192)  0           InceptionB0_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_1x7_1_conv  (None, 17, 17, 192)  258048      InceptionB0_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB0_branch0_1x7_1_bn (B (None, 17, 17, 192)  768         InceptionB0_branch0_1x7_1_conv[0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_1x7_1_relu  (None, 17, 17, 192)  0           InceptionB0_branch0_1x7_1_bn[0][0
# __________________________________________________________________________________________________
# InceptionB0_branch0_7x1_1_conv  (None, 17, 17, 224)  301056      InceptionB0_branch0_1x7_1_relu[0]
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv1x1_con (None, 17, 17, 192)  196608      ReductionA_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_7x1_1_bn (B (None, 17, 17, 224)  896         InceptionB0_branch0_7x1_1_conv[0]
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv1x1_bn  (None, 17, 17, 192)  768         InceptionB0_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB0_branch0_7x1_1_relu  (None, 17, 17, 224)  0           InceptionB0_branch0_7x1_1_bn[0][0
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv1x1_rel (None, 17, 17, 192)  0           InceptionB0_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_1x7_2_conv  (None, 17, 17, 224)  351232      InceptionB0_branch0_7x1_1_relu[0]
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv7x7_1_c (None, 17, 17, 224)  301056      InceptionB0_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB0_branch0_1x7_2_bn (B (None, 17, 17, 224)  896         InceptionB0_branch0_1x7_2_conv[0]
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv7x7_1_b (None, 17, 17, 224)  896         InceptionB0_branch1_conv7x7_1_con
# __________________________________________________________________________________________________
# InceptionB0_branch0_1x7_2_relu  (None, 17, 17, 224)  0           InceptionB0_branch0_1x7_2_bn[0][0
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv7x7_1_r (None, 17, 17, 224)  0           InceptionB0_branch1_conv7x7_1_bn[
# __________________________________________________________________________________________________
# InceptionB0_branch3_pool (Avera (None, 17, 17, 1024) 0           ReductionA_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_7x1_2_conv  (None, 17, 17, 256)  401408      InceptionB0_branch0_1x7_2_relu[0]
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv7x7_2_c (None, 17, 17, 256)  401408      InceptionB0_branch1_conv7x7_1_rel
# __________________________________________________________________________________________________
# InceptionB0_branch2_conv1x1_con (None, 17, 17, 384)  393216      ReductionA_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB0_branch3_conv1x1_con (None, 17, 17, 128)  131072      InceptionB0_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionB0_branch0_7x1_2_bn (B (None, 17, 17, 256)  1024        InceptionB0_branch0_7x1_2_conv[0]
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv7x7_2_b (None, 17, 17, 256)  1024        InceptionB0_branch1_conv7x7_2_con
# __________________________________________________________________________________________________
# InceptionB0_branch2_conv1x1_bn  (None, 17, 17, 384)  1536        InceptionB0_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB0_branch3_conv1x1_bn  (None, 17, 17, 128)  512         InceptionB0_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB0_branch0_7x1_2_relu  (None, 17, 17, 256)  0           InceptionB0_branch0_7x1_2_bn[0][0
# __________________________________________________________________________________________________
# InceptionB0_branch1_conv7x7_2_r (None, 17, 17, 256)  0           InceptionB0_branch1_conv7x7_2_bn[
# __________________________________________________________________________________________________
# InceptionB0_branch2_conv1x1_rel (None, 17, 17, 384)  0           InceptionB0_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB0_branch3_conv1x1_rel (None, 17, 17, 128)  0           InceptionB0_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB0_concat (Concatenate (None, 17, 17, 1024) 0           InceptionB0_branch0_7x1_2_relu[0]
#                                                                  InceptionB0_branch1_conv7x7_2_rel
#                                                                  InceptionB0_branch2_conv1x1_relu[
#                                                                  InceptionB0_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB1_branch0_conv1x1_con (None, 17, 17, 192)  196608      InceptionB0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_conv1x1_bn  (None, 17, 17, 192)  768         InceptionB1_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB1_branch0_conv1x1_rel (None, 17, 17, 192)  0           InceptionB1_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_1x7_1_conv  (None, 17, 17, 192)  258048      InceptionB1_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB1_branch0_1x7_1_bn (B (None, 17, 17, 192)  768         InceptionB1_branch0_1x7_1_conv[0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_1x7_1_relu  (None, 17, 17, 192)  0           InceptionB1_branch0_1x7_1_bn[0][0
# __________________________________________________________________________________________________
# InceptionB1_branch0_7x1_1_conv  (None, 17, 17, 224)  301056      InceptionB1_branch0_1x7_1_relu[0]
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv1x1_con (None, 17, 17, 192)  196608      InceptionB0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_7x1_1_bn (B (None, 17, 17, 224)  896         InceptionB1_branch0_7x1_1_conv[0]
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv1x1_bn  (None, 17, 17, 192)  768         InceptionB1_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB1_branch0_7x1_1_relu  (None, 17, 17, 224)  0           InceptionB1_branch0_7x1_1_bn[0][0
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv1x1_rel (None, 17, 17, 192)  0           InceptionB1_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_1x7_2_conv  (None, 17, 17, 224)  351232      InceptionB1_branch0_7x1_1_relu[0]
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv7x7_1_c (None, 17, 17, 224)  301056      InceptionB1_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB1_branch0_1x7_2_bn (B (None, 17, 17, 224)  896         InceptionB1_branch0_1x7_2_conv[0]
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv7x7_1_b (None, 17, 17, 224)  896         InceptionB1_branch1_conv7x7_1_con
# __________________________________________________________________________________________________
# InceptionB1_branch0_1x7_2_relu  (None, 17, 17, 224)  0           InceptionB1_branch0_1x7_2_bn[0][0
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv7x7_1_r (None, 17, 17, 224)  0           InceptionB1_branch1_conv7x7_1_bn[
# __________________________________________________________________________________________________
# InceptionB1_branch3_pool (Avera (None, 17, 17, 1024) 0           InceptionB0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_7x1_2_conv  (None, 17, 17, 256)  401408      InceptionB1_branch0_1x7_2_relu[0]
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv7x7_2_c (None, 17, 17, 256)  401408      InceptionB1_branch1_conv7x7_1_rel
# __________________________________________________________________________________________________
# InceptionB1_branch2_conv1x1_con (None, 17, 17, 384)  393216      InceptionB0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB1_branch3_conv1x1_con (None, 17, 17, 128)  131072      InceptionB1_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionB1_branch0_7x1_2_bn (B (None, 17, 17, 256)  1024        InceptionB1_branch0_7x1_2_conv[0]
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv7x7_2_b (None, 17, 17, 256)  1024        InceptionB1_branch1_conv7x7_2_con
# __________________________________________________________________________________________________
# InceptionB1_branch2_conv1x1_bn  (None, 17, 17, 384)  1536        InceptionB1_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB1_branch3_conv1x1_bn  (None, 17, 17, 128)  512         InceptionB1_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB1_branch0_7x1_2_relu  (None, 17, 17, 256)  0           InceptionB1_branch0_7x1_2_bn[0][0
# __________________________________________________________________________________________________
# InceptionB1_branch1_conv7x7_2_r (None, 17, 17, 256)  0           InceptionB1_branch1_conv7x7_2_bn[
# __________________________________________________________________________________________________
# InceptionB1_branch2_conv1x1_rel (None, 17, 17, 384)  0           InceptionB1_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB1_branch3_conv1x1_rel (None, 17, 17, 128)  0           InceptionB1_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB1_concat (Concatenate (None, 17, 17, 1024) 0           InceptionB1_branch0_7x1_2_relu[0]
#                                                                  InceptionB1_branch1_conv7x7_2_rel
#                                                                  InceptionB1_branch2_conv1x1_relu[
#                                                                  InceptionB1_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB2_branch0_conv1x1_con (None, 17, 17, 192)  196608      InceptionB1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB2_branch0_conv1x1_bn  (None, 17, 17, 192)  768         InceptionB2_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB2_branch0_conv1x1_rel (None, 17, 17, 192)  0           InceptionB2_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB2_branch0_1x7_1_conv  (None, 17, 17, 192)  258048      InceptionB2_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB2_branch0_1x7_1_bn (B (None, 17, 17, 192)  768         InceptionB2_branch0_1x7_1_conv[0]
# __________________________________________________________________________________________________
# InceptionB2_branch0_1x7_1_relu  (None, 17, 17, 192)  0           InceptionB2_branch0_1x7_1_bn[0][0
# __________________________________________________________________________________________________
# InceptionB2_branch0_7x1_1_conv  (None, 17, 17, 224)  301056      InceptionB2_branch0_1x7_1_relu[0]
# __________________________________________________________________________________________________
# InceptionB2_branch1_conv1x1_con (None, 17, 17, 192)  196608      InceptionB1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB2_branch0_7x1_1_bn (B (None, 17, 17, 224)  896         InceptionB2_branch0_7x1_1_conv[0]
# __________________________________________________________________________________________________
# InceptionB2_branch1_conv1x1_bn  (None, 17, 17, 192)  768         InceptionB2_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionB2_branch0_7x1_1_relu  (None, 17, 17, 224)  0           InceptionB2_branch0_7x1_1_bn[0][0
# __________________________________________________________________________________________________
# InceptionB2_branch1_conv1x1_rel (None, 17, 17, 192)  0           InceptionB2_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionB2_branch0_1x7_2_conv  (None, 17, 17, 224)  351232      InceptionB2_branch0_7x1_1_relu[0]
# __________________________________________________________________________________________________
# InceptionB2_branch1_conv7x7_1_c (None, 17, 17, 224)  301056      InceptionB2_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionB2_branch0_1x7_2_bn (B (None, 17, 17, 224)  896         InceptionB2_branch0_1x7_2_conv[0]
# __________________________________________________________________________________________________
# InceptionB2_branch1_conv7x7_1_b (None, 17, 17, 224)  896         InceptionB2_branch1_conv7x7_1_con
# __________________________________________________________________________________________________
# InceptionB2_branch0_1x7_2_relu  (None, 17, 17, 224)  0           InceptionB2_branch0_1x7_2_bn[0][0
# __________________________________________________________________________________________________
# InceptionB2_branch1_conv7x7_1_r (None, 17, 17, 224)  0           InceptionB2_branch1_conv7x7_1_bn[
# __________________________________________________________________________________________________
# InceptionB2_branch3_pool (Avera (None, 17, 17, 1024) 0           InceptionB1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionB2_branch0_7x1_2_conv  (None, 17, 17, 256)  401408      InceptionB2_branch0_1x7_2_relu[0]
# __________________________________________________________________________________________________
# ...
# InceptionC0_branch3_conv1x1_rel (None, 8, 8, 256)    0           InceptionC0_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC0_concat (Concatenate (None, 8, 8, 1536)   0           InceptionC0_branch0_concat[0][0]
#                                                                  InceptionC0_branch1_concat[0][0]
#                                                                  InceptionC0_branch2_conv1x1_relu[
#                                                                  InceptionC0_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x1_con (None, 8, 8, 384)    589824      InceptionC0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x1_bn  (None, 8, 8, 384)    1536        InceptionC1_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x1_rel (None, 8, 8, 384)    0           InceptionC1_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x3_con (None, 8, 8, 448)    516096      InceptionC1_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x3_bn  (None, 8, 8, 448)    1792        InceptionC1_branch0_conv1x3_conv[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x3_rel (None, 8, 8, 448)    0           InceptionC1_branch0_conv1x3_bn[0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv3x1_con (None, 8, 8, 512)    688128      InceptionC1_branch0_conv1x3_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv1x1_con (None, 8, 8, 384)    589824      InceptionC0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv3x1_bn  (None, 8, 8, 512)    2048        InceptionC1_branch0_conv3x1_conv[
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv1x1_bn  (None, 8, 8, 384)    1536        InceptionC1_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv3x1_rel (None, 8, 8, 512)    0           InceptionC1_branch0_conv3x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv1x1_rel (None, 8, 8, 384)    0           InceptionC1_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x3_r_c (None, 8, 8, 256)    393216      InceptionC1_branch0_conv3x1_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv3x1_l_c (None, 8, 8, 256)    393216      InceptionC1_branch0_conv3x1_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv1x3_l_c (None, 8, 8, 256)    294912      InceptionC1_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv3x1_r_c (None, 8, 8, 256)    294912      InceptionC1_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC1_branch3_pool (Avera (None, 8, 8, 1536)   0           InceptionC0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x3_r_b (None, 8, 8, 256)    1024        InceptionC1_branch0_conv1x3_r_con
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv3x1_l_b (None, 8, 8, 256)    1024        InceptionC1_branch0_conv3x1_l_con
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv1x3_l_b (None, 8, 8, 256)    1024        InceptionC1_branch1_conv1x3_l_con
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv3x1_r_b (None, 8, 8, 256)    1024        InceptionC1_branch1_conv3x1_r_con
# __________________________________________________________________________________________________
# InceptionC1_branch2_conv1x1_con (None, 8, 8, 256)    393216      InceptionC0_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC1_branch3_conv1x1_con (None, 8, 8, 256)    393216      InceptionC1_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv1x3_r_r (None, 8, 8, 256)    0           InceptionC1_branch0_conv1x3_r_bn[
# __________________________________________________________________________________________________
# InceptionC1_branch0_conv3x1_l_r (None, 8, 8, 256)    0           InceptionC1_branch0_conv3x1_l_bn[
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv1x3_l_r (None, 8, 8, 256)    0           InceptionC1_branch1_conv1x3_l_bn[
# __________________________________________________________________________________________________
# InceptionC1_branch1_conv3x1_r_r (None, 8, 8, 256)    0           InceptionC1_branch1_conv3x1_r_bn[
# __________________________________________________________________________________________________
# InceptionC1_branch2_conv1x1_bn  (None, 8, 8, 256)    1024        InceptionC1_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC1_branch3_conv1x1_bn  (None, 8, 8, 256)    1024        InceptionC1_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC1_branch0_concat (Con (None, 8, 8, 512)    0           InceptionC1_branch0_conv1x3_r_rel
#                                                                  InceptionC1_branch0_conv3x1_l_rel
# __________________________________________________________________________________________________
# InceptionC1_branch1_concat (Con (None, 8, 8, 512)    0           InceptionC1_branch1_conv1x3_l_rel
#                                                                  InceptionC1_branch1_conv3x1_r_rel
# __________________________________________________________________________________________________
# InceptionC1_branch2_conv1x1_rel (None, 8, 8, 256)    0           InceptionC1_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC1_branch3_conv1x1_rel (None, 8, 8, 256)    0           InceptionC1_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC1_concat (Concatenate (None, 8, 8, 1536)   0           InceptionC1_branch0_concat[0][0]
#                                                                  InceptionC1_branch1_concat[0][0]
#                                                                  InceptionC1_branch2_conv1x1_relu[
#                                                                  InceptionC1_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x1_con (None, 8, 8, 384)    589824      InceptionC1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x1_bn  (None, 8, 8, 384)    1536        InceptionC2_branch0_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x1_rel (None, 8, 8, 384)    0           InceptionC2_branch0_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x3_con (None, 8, 8, 448)    516096      InceptionC2_branch0_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x3_bn  (None, 8, 8, 448)    1792        InceptionC2_branch0_conv1x3_conv[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x3_rel (None, 8, 8, 448)    0           InceptionC2_branch0_conv1x3_bn[0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv3x1_con (None, 8, 8, 512)    688128      InceptionC2_branch0_conv1x3_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv1x1_con (None, 8, 8, 384)    589824      InceptionC1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv3x1_bn  (None, 8, 8, 512)    2048        InceptionC2_branch0_conv3x1_conv[
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv1x1_bn  (None, 8, 8, 384)    1536        InceptionC2_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv3x1_rel (None, 8, 8, 512)    0           InceptionC2_branch0_conv3x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv1x1_rel (None, 8, 8, 384)    0           InceptionC2_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x3_r_c (None, 8, 8, 256)    393216      InceptionC2_branch0_conv3x1_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv3x1_l_c (None, 8, 8, 256)    393216      InceptionC2_branch0_conv3x1_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv1x3_l_c (None, 8, 8, 256)    294912      InceptionC2_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv3x1_r_c (None, 8, 8, 256)    294912      InceptionC2_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# InceptionC2_branch3_pool (Avera (None, 8, 8, 1536)   0           InceptionC1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x3_r_b (None, 8, 8, 256)    1024        InceptionC2_branch0_conv1x3_r_con
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv3x1_l_b (None, 8, 8, 256)    1024        InceptionC2_branch0_conv3x1_l_con
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv1x3_l_b (None, 8, 8, 256)    1024        InceptionC2_branch1_conv1x3_l_con
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv3x1_r_b (None, 8, 8, 256)    1024        InceptionC2_branch1_conv3x1_r_con
# __________________________________________________________________________________________________
# InceptionC2_branch2_conv1x1_con (None, 8, 8, 256)    393216      InceptionC1_concat[0][0]
# __________________________________________________________________________________________________
# InceptionC2_branch3_conv1x1_con (None, 8, 8, 256)    393216      InceptionC2_branch3_pool[0][0]
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv1x3_r_r (None, 8, 8, 256)    0           InceptionC2_branch0_conv1x3_r_bn[
# __________________________________________________________________________________________________
# InceptionC2_branch0_conv3x1_l_r (None, 8, 8, 256)    0           InceptionC2_branch0_conv3x1_l_bn[
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv1x3_l_r (None, 8, 8, 256)    0           InceptionC2_branch1_conv1x3_l_bn[
# __________________________________________________________________________________________________
# InceptionC2_branch1_conv3x1_r_r (None, 8, 8, 256)    0           InceptionC2_branch1_conv3x1_r_bn[
# __________________________________________________________________________________________________
# InceptionC2_branch2_conv1x1_bn  (None, 8, 8, 256)    1024        InceptionC2_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC2_branch3_conv1x1_bn  (None, 8, 8, 256)    1024        InceptionC2_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# InceptionC2_branch0_concat (Con (None, 8, 8, 512)    0           InceptionC2_branch0_conv1x3_r_rel
#                                                                  InceptionC2_branch0_conv3x1_l_rel
# __________________________________________________________________________________________________
# InceptionC2_branch1_concat (Con (None, 8, 8, 512)    0           InceptionC2_branch1_conv1x3_l_rel
#                                                                  InceptionC2_branch1_conv3x1_r_rel
# __________________________________________________________________________________________________
# InceptionC2_branch2_conv1x1_rel (None, 8, 8, 256)    0           InceptionC2_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC2_branch3_conv1x1_rel (None, 8, 8, 256)    0           InceptionC2_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# InceptionC2_concat (Concatenate (None, 8, 8, 1536)   0           InceptionC2_branch0_concat[0][0]
#                                                                  InceptionC2_branch1_concat[0][0]
#                                                                  InceptionC2_branch2_conv1x1_relu[
#                                                                  InceptionC2_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# globalaveragepooling (GlobalAve (None, 1536)         0           InceptionC2_concat[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1536)         0           globalaveragepooling[0][0]
# __________________________________________________________________________________________________
# classificaiton (Dense)          (None, 1000)         1537000     dropout_1[0][0]
# ==================================================================================================
# Total params: 42,742,984
# Trainable params: 42,679,816
# Non-trainable params: 63,168
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## 参考文献
# (1)Szegedy C, Ioffe S, Vanhoucke V, et al. Inception-v4, inception-resnet and the impact of residual connections on learning[C]//AAAI. 2017, 4: 12.
