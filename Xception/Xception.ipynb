# %% [markdown]
# ## 算法说明

# %% [markdown]
# Xception是对Inception v3的另一种改进，采用depthwise separable convolution来替换原来Inception v3中的卷积操作。
# 下面对depthwise separable convolution进行简单介绍：
#
# depthwise separable convolution包含两个过程：depthwise convolution 和 pointwise convolution：
# - depthwise convolution对输入的每一个channel独立的用对应channel的所有卷积核去卷积。假设卷积核的shape是[ filter_height, filter_width, in_channels, channel_multiplier ]，那么每个in_channel会输出channel_multiplier那么多个通道，最后的feature map就会有in_channels * channel_multiplier个通道了。
# - pointwise convolution是 1x1 卷积操作，是对多个分散通道进行融合的操作。
# 具体操作如下图所示：
# ![pic0](pic0.png)
#
# Xception是基于depthwise separable convolution构建的分类架构，其网络架构如图所示：
# ![pic1](pic1.png)
# 基于上述架构图，对Xception进行编码实现。

# %% [markdown]
# ## 算法实现

# %%
import keras

def middle_flow(x, block, name=None):
    '''
    middle flow block
    :param x: input tensor
    :param block: index of block for name
    :param name: operation name
    :return: output tensor
    '''
    shortcut = x
    x = keras.layers.Activation('relu', name=name+str(block)+'_relu0')(x)
    x = keras.layers.SeparableConv2D(filters=728, kernel_size=(3,3), padding='same', name=name+'_res'+str(block)+'_SepConv0')(x)
    x = keras.layers.BatchNormalization(name=name+str(block)+'_bn0')(x)
    x = keras.layers.Activation('relu', name=name+str(block)+'_relu1')(x)
    x = keras.layers.SeparableConv2D(filters=728, kernel_size=(3,3), padding='same', name=name+str(block)+'_SepConv1')(x)
    x = keras.layers.BatchNormalization(name=name+str(block)+'_bn1')(x)
    x = keras.layers.Activation('relu', name=name+str(block)+'_relu2')(x)
    x = keras.layers.SeparableConv2D(filters=728, kernel_size=(3,3), padding='same', name=name+str(block)+'_SepConv2')(x)
    x = keras.layers.BatchNormalization(name=name+str(block)+'_bn2')(x)
    x = keras.layers.Add(name=name+str(block)+'_add')([shortcut, x])
    return x

def Xception(input_shape=(299,299,3), classes = 1000, use_dropout = True, dropout_rate = 0.2):
    
    # Entry flow 1
    x_input = keras.layers.Input(shape=input_shape, name='input_layer')
    x = keras.layers.Conv2D(filters=32, kernel_size=(3,3), strides=2, padding='same', name='entryflow_conv0')(x_input)
    x = keras.layers.BatchNormalization(name='entryflow_bn0')(x)
    x = keras.layers.Activation('relu', name='entryflow_relu0')(x)  
    x = keras.layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', name='entryflow_conv1')(x)
    x = keras.layers.BatchNormalization(name='entryflow_bn1')(x)
    x = keras.layers.Activation('relu', name='entryflow_relu1')(x)
    
    # Entry flow 2
    shortcut = keras.layers.Conv2D(filters=128, kernel_size=(1,1), strides=2, padding='valid', name='entryflow_res0_shortcut')(x)
    shortcut = keras.layers.BatchNormalization(name='entryflow_res0_shortcutbn')(shortcut) 
    x = keras.layers.SeparableConv2D(filters=128, kernel_size=(3,3), padding='same', name='entryflow_res0_SepConv0')(x)
    x = keras.layers.BatchNormalization(name='entryflow_res0_bn0')(x)
    x = keras.layers.Activation('relu', name='entryflow_res0_relu0')(x)
    x = keras.layers.SeparableConv2D(filters=128, kernel_size=(3,3),padding='same', name='entryflow_res0_SepConv1')(x)
    x = keras.layers.BatchNormalization(name='entryflow_res0_bn1')(x)
    x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=2, padding='same', name='entryflow_res0_pool')(x)
    x = keras.layers.Add(name='entryflow_res0_add')([shortcut, x])
    
    #Entry flow 3
    shortcut = keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=2, padding='same', name='entryflow_res1_shortcut')(x)
    shortcut = keras.layers.BatchNormalization(name='entryflow_res1_shortcutbn')(shortcut)
    x = keras.layers.Activation('relu', name='entryflow_res1_relu0')(x)
    x = keras.layers.SeparableConv2D(filters=256, kernel_size=(3,3), padding='same', name='entryflow_res1_SepConv0')(x)
    x = keras.layers.BatchNormalization(name='entryflow_res1_bn0')(x)
    x = keras.layers.Activation('relu', name='entryflow_res1_relu1')(x)
    x = keras.layers.SeparableConv2D(filters=256, kernel_size=(3,3), padding='same', name='entryflow_res1_SepConv1')(x)
    x = keras.layers.BatchNormalization(name='entryflow_res1_bn1')(x)
    x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=2, padding='same', name='entryflow_res1_pool')(x)  
    x = keras.layers.Add(name='entryflow_res1_add')([shortcut, x])
    
    #Entry flow 4
    shortcut = keras.layers.Conv2D(filters=728, kernel_size=(1,1), strides=2, padding='same', name='entryflow_res2_shortcut')(x)
    shortcut = keras.layers.BatchNormalization(name='entryflow_res2_shortcutbn')(shortcut)
    x = keras.layers.Activation('relu', name='entryflow_res2_relu0')(x)
    x = keras.layers.SeparableConv2D(filters=728, kernel_size=(3,3), padding='same', name='entryflow_res2_SepConv0')(x)
    x = keras.layers.BatchNormalization(name='entryflow_res2_bn0')(x)
    x = keras.layers.Activation('relu', name='entryflow_res2_relu1')(x)
    x = keras.layers.SeparableConv2D(filters=728, kernel_size=(3,3), padding='same', name='entryflow_res2_SepConv1')(x)
    x = keras.layers.BatchNormalization(name='entryflow_res2_bn1')(x)
    x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=2, padding='same', name='entryflow_res2_pool')(x)
    x = keras.layers.Add(name='entryflow_res2_add')([shortcut, x])
    
    #Middle flow
    #重复8次
    for i in range(8):
        x = middle_flow(x, i+3, name='middleflow')
    
    #Exit flow
    shortcut = keras.layers.Conv2D(filters=1024, kernel_size=(1,1), strides=2, padding='same', name='exitflow_shortcut')(x)
    shortcut = keras.layers.BatchNormalization(name='exitflow_shortcutbn')(shortcut)
    x = keras.layers.Activation('relu', name='exitflow_relu0')(x)
    x = keras.layers.SeparableConv2D(filters=728, kernel_size=(3,3), padding='same', name='exitflow_SepConv0')(x)
    x = keras.layers.BatchNormalization(name='exitflow_bn0')(x)
    x = keras.layers.Activation('relu', name='exitflow_relu1')(x)
    x = keras.layers.SeparableConv2D(filters=1024, kernel_size=(3,3), padding='same', name='exitflow_SepConv1')(x)
    x = keras.layers.BatchNormalization(name='exitflow_bn1')(x)
    x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=2, padding='same', name='exitflow_pool')(x)   
    x = keras.layers.Add(name='exitflow_add')([shortcut, x])
    
    x = keras.layers.SeparableConv2D(filters=1536, kernel_size=(3,3), padding='same', name='exitflow_SepConv2')(x)
    x = keras.layers.BatchNormalization(name='exitflow_bn2')(x)
    x = keras.layers.Activation('relu', name='exitflow_relu2')(x)
    x = keras.layers.SeparableConv2D(filters=2048, kernel_size=(3,3), padding='same', name='exitflow_SepConv3')(x)
    x = keras.layers.BatchNormalization(name='exitflow_bn3')(x)
    x = keras.layers.Activation('relu', name='exitflow_relu3')(x)
    
    x = keras.layers.GlobalAveragePooling2D(name='exitflow_globalaveragepool')(x)
    
    #dense layer
    #dropout
    if use_dropout:
        x = keras.layers.Dropout(dropout_rate)(x)
        
    #dense-layer
    x = keras.layers.Dense(units = classes, activation='softmax', kernel_initializer='glorot_uniform', name = 'fc' + str(classes))(x)
    model = keras.models.Model(inputs = x_input, outputs = x, name = 'Xception')
    return model

# %%
model = Xception()
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# entryflow_conv0 (Conv2D)        (None, 150, 150, 32) 896         input_layer[0][0]
# __________________________________________________________________________________________________
# entryflow_bn0 (BatchNormalizati (None, 150, 150, 32) 128         entryflow_conv0[0][0]
# __________________________________________________________________________________________________
# entryflow_relu0 (Activation)    (None, 150, 150, 32) 0           entryflow_bn0[0][0]
# __________________________________________________________________________________________________
# entryflow_conv1 (Conv2D)        (None, 150, 150, 64) 18496       entryflow_relu0[0][0]
# __________________________________________________________________________________________________
# entryflow_bn1 (BatchNormalizati (None, 150, 150, 64) 256         entryflow_conv1[0][0]
# __________________________________________________________________________________________________
# entryflow_relu1 (Activation)    (None, 150, 150, 64) 0           entryflow_bn1[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_SepConv0 (Separa (None, 150, 150, 128 8896        entryflow_relu1[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_bn0 (BatchNormal (None, 150, 150, 128 512         entryflow_res0_SepConv0[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_relu0 (Activatio (None, 150, 150, 128 0           entryflow_res0_bn0[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_SepConv1 (Separa (None, 150, 150, 128 17664       entryflow_res0_relu0[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_shortcut (Conv2D (None, 75, 75, 128)  8320        entryflow_relu1[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_bn1 (BatchNormal (None, 150, 150, 128 512         entryflow_res0_SepConv1[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_shortcutbn (Batc (None, 75, 75, 128)  512         entryflow_res0_shortcut[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_pool (MaxPooling (None, 75, 75, 128)  0           entryflow_res0_bn1[0][0]
# __________________________________________________________________________________________________
# entryflow_res0_add (Add)        (None, 75, 75, 128)  0           entryflow_res0_shortcutbn[0][0]
#                                                                  entryflow_res0_pool[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_relu0 (Activatio (None, 75, 75, 128)  0           entryflow_res0_add[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_SepConv0 (Separa (None, 75, 75, 256)  34176       entryflow_res1_relu0[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_bn0 (BatchNormal (None, 75, 75, 256)  1024        entryflow_res1_SepConv0[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_relu1 (Activatio (None, 75, 75, 256)  0           entryflow_res1_bn0[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_SepConv1 (Separa (None, 75, 75, 256)  68096       entryflow_res1_relu1[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_shortcut (Conv2D (None, 38, 38, 256)  33024       entryflow_res0_add[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_bn1 (BatchNormal (None, 75, 75, 256)  1024        entryflow_res1_SepConv1[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_shortcutbn (Batc (None, 38, 38, 256)  1024        entryflow_res1_shortcut[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_pool (MaxPooling (None, 38, 38, 256)  0           entryflow_res1_bn1[0][0]
# __________________________________________________________________________________________________
# entryflow_res1_add (Add)        (None, 38, 38, 256)  0           entryflow_res1_shortcutbn[0][0]
#                                                                  entryflow_res1_pool[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_relu0 (Activatio (None, 38, 38, 256)  0           entryflow_res1_add[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_SepConv0 (Separa (None, 38, 38, 728)  189400      entryflow_res2_relu0[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_bn0 (BatchNormal (None, 38, 38, 728)  2912        entryflow_res2_SepConv0[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_relu1 (Activatio (None, 38, 38, 728)  0           entryflow_res2_bn0[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_SepConv1 (Separa (None, 38, 38, 728)  537264      entryflow_res2_relu1[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_shortcut (Conv2D (None, 19, 19, 728)  187096      entryflow_res1_add[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_bn1 (BatchNormal (None, 38, 38, 728)  2912        entryflow_res2_SepConv1[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_shortcutbn (Batc (None, 19, 19, 728)  2912        entryflow_res2_shortcut[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_pool (MaxPooling (None, 19, 19, 728)  0           entryflow_res2_bn1[0][0]
# __________________________________________________________________________________________________
# entryflow_res2_add (Add)        (None, 19, 19, 728)  0           entryflow_res2_shortcutbn[0][0]
#                                                                  entryflow_res2_pool[0][0]
# __________________________________________________________________________________________________
# middleflow3_relu0 (Activation)  (None, 19, 19, 728)  0           entryflow_res2_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res3_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow3_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow3_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res3_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow3_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow3_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow3_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow3_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow3_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow3_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow3_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow3_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow3_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow3_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow3_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow3_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow3_add (Add)           (None, 19, 19, 728)  0           entryflow_res2_add[0][0]
#                                                                  middleflow3_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow4_relu0 (Activation)  (None, 19, 19, 728)  0           middleflow3_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res4_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow4_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow4_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res4_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow4_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow4_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow4_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow4_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow4_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow4_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow4_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow4_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow4_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow4_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow4_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow4_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow4_add (Add)           (None, 19, 19, 728)  0           middleflow3_add[0][0]
#                                                                  middleflow4_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow5_relu0 (Activation)  (None, 19, 19, 728)  0           middleflow4_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res5_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow5_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow5_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res5_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow5_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow5_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow5_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow5_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow5_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow5_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow5_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow5_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow5_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow5_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow5_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow5_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow5_add (Add)           (None, 19, 19, 728)  0           middleflow4_add[0][0]
#                                                                  middleflow5_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow6_relu0 (Activation)  (None, 19, 19, 728)  0           middleflow5_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res6_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow6_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow6_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res6_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow6_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow6_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow6_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow6_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow6_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow6_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow6_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow6_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow6_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow6_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow6_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow6_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow6_add (Add)           (None, 19, 19, 728)  0           middleflow5_add[0][0]
#                                                                  middleflow6_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow7_relu0 (Activation)  (None, 19, 19, 728)  0           middleflow6_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res7_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow7_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow7_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res7_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow7_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow7_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow7_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow7_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow7_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow7_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow7_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow7_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow7_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow7_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow7_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow7_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow7_add (Add)           (None, 19, 19, 728)  0           middleflow6_add[0][0]
#                                                                  middleflow7_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow8_relu0 (Activation)  (None, 19, 19, 728)  0           middleflow7_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res8_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow8_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow8_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res8_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow8_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow8_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow8_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow8_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow8_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow8_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow8_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow8_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow8_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow8_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow8_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow8_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow8_add (Add)           (None, 19, 19, 728)  0           middleflow7_add[0][0]
#                                                                  middleflow8_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow9_relu0 (Activation)  (None, 19, 19, 728)  0           middleflow8_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res9_SepConv0 (Separ (None, 19, 19, 728)  537264      middleflow9_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow9_bn0 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow_res9_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow9_relu1 (Activation)  (None, 19, 19, 728)  0           middleflow9_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow9_SepConv1 (Separable (None, 19, 19, 728)  537264      middleflow9_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow9_bn1 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow9_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow9_relu2 (Activation)  (None, 19, 19, 728)  0           middleflow9_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow9_SepConv2 (Separable (None, 19, 19, 728)  537264      middleflow9_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow9_bn2 (BatchNormaliza (None, 19, 19, 728)  2912        middleflow9_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow9_add (Add)           (None, 19, 19, 728)  0           middleflow8_add[0][0]
#                                                                  middleflow9_bn2[0][0]
# __________________________________________________________________________________________________
# middleflow10_relu0 (Activation) (None, 19, 19, 728)  0           middleflow9_add[0][0]
# __________________________________________________________________________________________________
# middleflow_res10_SepConv0 (Sepa (None, 19, 19, 728)  537264      middleflow10_relu0[0][0]
# __________________________________________________________________________________________________
# middleflow10_bn0 (BatchNormaliz (None, 19, 19, 728)  2912        middleflow_res10_SepConv0[0][0]
# __________________________________________________________________________________________________
# middleflow10_relu1 (Activation) (None, 19, 19, 728)  0           middleflow10_bn0[0][0]
# __________________________________________________________________________________________________
# middleflow10_SepConv1 (Separabl (None, 19, 19, 728)  537264      middleflow10_relu1[0][0]
# __________________________________________________________________________________________________
# middleflow10_bn1 (BatchNormaliz (None, 19, 19, 728)  2912        middleflow10_SepConv1[0][0]
# __________________________________________________________________________________________________
# middleflow10_relu2 (Activation) (None, 19, 19, 728)  0           middleflow10_bn1[0][0]
# __________________________________________________________________________________________________
# middleflow10_SepConv2 (Separabl (None, 19, 19, 728)  537264      middleflow10_relu2[0][0]
# __________________________________________________________________________________________________
# middleflow10_bn2 (BatchNormaliz (None, 19, 19, 728)  2912        middleflow10_SepConv2[0][0]
# __________________________________________________________________________________________________
# middleflow10_add (Add)          (None, 19, 19, 728)  0           middleflow9_add[0][0]
#                                                                  middleflow10_bn2[0][0]
# __________________________________________________________________________________________________
# exitflow_relu0 (Activation)     (None, 19, 19, 728)  0           middleflow10_add[0][0]
# __________________________________________________________________________________________________
# exitflow_SepConv0 (SeparableCon (None, 19, 19, 728)  537264      exitflow_relu0[0][0]
# __________________________________________________________________________________________________
# exitflow_bn0 (BatchNormalizatio (None, 19, 19, 728)  2912        exitflow_SepConv0[0][0]
# __________________________________________________________________________________________________
# exitflow_relu1 (Activation)     (None, 19, 19, 728)  0           exitflow_bn0[0][0]
# __________________________________________________________________________________________________
# exitflow_SepConv1 (SeparableCon (None, 19, 19, 1024) 753048      exitflow_relu1[0][0]
# __________________________________________________________________________________________________
# exitflow_shortcut (Conv2D)      (None, 10, 10, 1024) 746496      middleflow10_add[0][0]
# __________________________________________________________________________________________________
# exitflow_bn1 (BatchNormalizatio (None, 19, 19, 1024) 4096        exitflow_SepConv1[0][0]
# __________________________________________________________________________________________________
# exitflow_shortcutbn (BatchNorma (None, 10, 10, 1024) 4096        exitflow_shortcut[0][0]
# __________________________________________________________________________________________________
# exitflow_pool (MaxPooling2D)    (None, 10, 10, 1024) 0           exitflow_bn1[0][0]
# __________________________________________________________________________________________________
# exitflow_add (Add)              (None, 10, 10, 1024) 0           exitflow_shortcutbn[0][0]
#                                                                  exitflow_pool[0][0]
# __________________________________________________________________________________________________
# exitflow_SepConv2 (SeparableCon (None, 10, 10, 1536) 1583616     exitflow_add[0][0]
# __________________________________________________________________________________________________
# exitflow_bn2 (BatchNormalizatio (None, 10, 10, 1536) 6144        exitflow_SepConv2[0][0]
# __________________________________________________________________________________________________
# exitflow_relu2 (Activation)     (None, 10, 10, 1536) 0           exitflow_bn2[0][0]
# __________________________________________________________________________________________________
# exitflow_SepConv3 (SeparableCon (None, 10, 10, 2048) 3161600     exitflow_relu2[0][0]
# __________________________________________________________________________________________________
# exitflow_bn3 (BatchNormalizatio (None, 10, 10, 2048) 8192        exitflow_SepConv3[0][0]
# __________________________________________________________________________________________________
# exitflow_relu3 (Activation)     (None, 10, 10, 2048) 0           exitflow_bn3[0][0]
# __________________________________________________________________________________________________
# exitflow_globalaveragepool (Glo (None, 2048)         0           exitflow_relu3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           exitflow_globalaveragepool[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 1000)         2049000     dropout_2[0][0]
# ==================================================================================================
# Total params: 22,937,744
# Trainable params: 22,883,216
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## 参考文献
# [1]Chollet F. Xception: Deep learning with depthwise separable convolutions[J]. arXiv preprint, 2017: 1610.02357.
