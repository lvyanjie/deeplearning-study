# %% [markdown]
# ## 算法介绍

# %% [markdown]
#   inception v2 在 inception v1的基础上进行了以下优化：
#
#   - 将大尺度卷积分解为多个小尺度卷积计算。如将一个5x5卷积替换为两个3x3卷积，在减少网络参数的同时提升了网络深度。
#   - 使用了BN操作代替LRN操作。
#
#   BN具体操作如下：
#
#   ![fig1](fig1.png)
#
#   其中，![CodeCogsEqn](CodeCogsEqn.png) 和 ![CodeCogsEqn2](CodeCogsEqn2.png) 是两个学习参数，网络可以通过这两个参数对于不需要BN操作的层消除BN操作影响
#
#   下表是inception v2 的结构：
#
#   ![fig2](fig2.png)
#
#   其中，结构中包含了以下两种inception module结构：
#
#   ![fig3](fig3.png)
#
#   ![fig8](fig8.png)
#
#   其中的inception 3a, 3b, 4a, 4b, 4c, 4d, 5a, 5b对应于第一种inception module结构，3c, 4e对应于第二种inception module结构，下面基于结构图对inception v2进行编码实现。

# %% [markdown]
# ## 算法实现

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
def conv_layer(x, filters, kernel_size, padding = 'same', strides = (1, 1), name = None):
    '''
    conv + bn + relu
    :param x: tensor, tensor of previous layer
    :param filters: integer, number of kernel
    :param kernel_size: tumple, kernel's (row, col)
    :param padding: 'same' or 'valid'
    :param strides: tumple, stride of kernel
    :param name: layer's name
    
    returns:
    output tensor
    '''
    x = keras.layers.Conv2D(filters, kernel_size, strides = strides, padding = padding, use_bias = False, name = name + '_conv')(x)
    x = keras.layers.BatchNormalization(axis = 3, name = name + '_bn')(x)
    x = keras.layers.Activation('relu', name = name + '_relu')(x)
    
    return x

# %%
## first inception module
def inceptionA(x,f_branch1_1x1,
              f_branch2_reduce3,
              f_branch2_3x3,
              f_branch3_reducedb3,
              f_branch3_db3,
              f_branch4_reducepool,
              name = None):
    '''
    inception A
    :param x: inpute tensor
    :param f_branch1_1x1: number of kernels 1x1
    :param f_branch2_reduce3: number of kernels 1x1 reducing 3x3
    :param f_branch2_3x3: number of kernels 3x3
    :param f_branch3_reducedb3: number of kernels 1x1 reducing double 3x3
    :param f_branch3_db3: list, number of kernels 3x3, 3x3
    :param f_branch3_reducepool: number of kernels 1x1 reducing pool
    
    returns:
    output tensor
    ''' 
    #conv1x1
    branch1 = conv_layer(x = x, filters = f_branch1_1x1, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    
    #conv 3x3
    branch2 = conv_layer(x = x, filters = f_branch2_reduce3, kernel_size = (1, 1), name = name + '_branch2_conv1x1')
    branch2 = conv_layer(x = branch2, filters = f_branch2_3x3, kernel_size = (3, 3), name = name + '_branch2_conv3x3')
    
    #conv double 3x3
    branch3 = conv_layer(x = x, filters = f_branch3_reducedb3, kernel_size = (1, 1), name = name + '_branch3_conv1x1')
    branch3 = conv_layer(x = branch3, filters = f_branch3_db3[0], kernel_size = (3, 3), name = name + '_branch3_conv3x3_1')
    branch3 = conv_layer(x = branch3, filters = f_branch3_db3[1], kernel_size = (3, 3), name = name + '_branch3_conv3x3_2')
    
    #pool
    branch4 = keras.layers.AveragePooling2D(pool_size = (3, 3), strides = (1, 1), padding = 'same', name = name + '_branch4_pool')(x)
    branch4 = conv_layer(x = branch4, filters = f_branch4_reducepool, kernel_size = (1, 1), padding = 'same', name = name + '_branch4_conv1x1')
    
    x = keras.layers.concatenate([branch1, branch2, branch3, branch4], axis = 3, name = name)
    return x

# %%
## second inception module
def inceptionB(x, f_branch1_reduce3,
              f_branch1_3x3,
              f_branch2_reducedb3,
              f_branch2_db3,
              name = None):
    '''
    inception B
    :param x: inpute tensor
    :parma f_branch1_reduce3: number of kernels 1x1 reducing 3x3
    :param f_branch1_3x3: number of kernels 3x3
    :param f_branch2_reducedb3: number of kernels 1x1 reducing double 3x3
    :param f_branch2_db3: list, number of kernels 3x3, 3x3
    
    returns:
    output tensor
    '''
    #conv1x1
    branch1 = conv_layer(x = x, filters = f_branch1_reduce3, kernel_size = (1, 1), name = name + '_branch1_conv1x1')
    branch1 = conv_layer(x = branch1, filters = f_branch1_3x3, kernel_size = (3, 3), strides = (2, 2), name = name + '_branch1_conv3x3')
    
    #conv double 3x3
    branch2 = conv_layer(x = x, filters = f_branch2_reducedb3, kernel_size = (1, 1), name = name + '_branch2_conv1x1')
    branch2 = conv_layer(x = branch2, filters = f_branch2_db3[0], kernel_size = (3, 3), name = name + '_branch2_conv3x3_1')
    branch2 = conv_layer(x = branch2, filters = f_branch2_db3[1], kernel_size = (3, 3), strides = (2, 2), name = name + '_branch2_conv3x3_2')
    
    #pool
    branch3 = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'same', name = name + '_branch3_pool')(x)
    
    x = keras.layers.concatenate([branch1, branch2, branch3], axis = 3, name = name)
    return x

# %%
def inceptionv2(input_shape=(224,224,3), classes = 1000, use_dropout = True, dropout_rate = 0.2):
    '''
    inception v2
    :param input_shape: tumple, input shape of net
    :param classes: integer, number of class
    :param use_dropout: bool, use dropout or not
    :param dropout: float, only valid if use_dropout = True
    
    returns:
    keras model
    '''
    #224*224*3
    x_input = keras.layers.Input(input_shape)
    
    #conv1
    x = conv_layer(x = x_input, filters = 64, kernel_size = (7, 7), strides = (2, 2), name = 'conv1')
    x = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'same', name = 'pool1')(x)
    
    #conv2
    x = conv_layer(x = x, filters = 192, kernel_size = (3, 3), name = 'conv2')
    x = keras.layers.MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = 'same', name = 'pool2')(x)
    
    #inception3a
    x = inceptionA(x = x,f_branch1_1x1 = 64,f_branch2_reduce3 = 64,f_branch2_3x3 = 64,f_branch3_reducedb3 = 64,f_branch3_db3 = [96, 96],f_branch4_reducepool = 32,name = 'inception3a')
    #inception3b
    x = inceptionA(x = x,f_branch1_1x1 = 64,f_branch2_reduce3 = 64,f_branch2_3x3 = 96,f_branch3_reducedb3 = 64,f_branch3_db3 = [96, 96],f_branch4_reducepool = 64,name = 'inception3b')
    #inception3c
    x = inceptionB(x = x, f_branch1_reduce3 = 128,f_branch1_3x3 = 160,f_branch2_reducedb3 = 64,f_branch2_db3 = [96, 96],name = 'inception3c')
    
    #inception4a
    x = inceptionA(x = x,f_branch1_1x1 = 224,f_branch2_reduce3 = 64,f_branch2_3x3 = 96,f_branch3_reducedb3 = 96,f_branch3_db3 = [128, 128],f_branch4_reducepool = 128,name = 'inception4a')
    #inception4b
    x = inceptionA(x = x,f_branch1_1x1 = 192,f_branch2_reduce3 = 96,f_branch2_3x3 = 128,f_branch3_reducedb3 = 96,f_branch3_db3 = [128, 128],f_branch4_reducepool = 128,name = 'inception4b')
    #inception4c
    x = inceptionA(x = x,f_branch1_1x1 = 160,f_branch2_reduce3 = 128,f_branch2_3x3 = 160,f_branch3_reducedb3 = 128,f_branch3_db3 = [160, 160],f_branch4_reducepool = 96,name = 'inception4c')
    #inception4d
    x = inceptionA(x = x,f_branch1_1x1 = 96,f_branch2_reduce3 = 128,f_branch2_3x3 = 192,f_branch3_reducedb3 = 160,f_branch3_db3 = [192, 192],f_branch4_reducepool = 96,name = 'inception4d')
    #inception4e
    x = inceptionB(x = x, f_branch1_reduce3 = 128,f_branch1_3x3 = 192,f_branch2_reducedb3 = 192,f_branch2_db3 = [256, 256],name = 'inception4e')
    
    #inception5a
    x = inceptionA(x = x,f_branch1_1x1 = 352,f_branch2_reduce3 = 192,f_branch2_3x3 = 320,f_branch3_reducedb3 = 160,f_branch3_db3 = [224, 224],f_branch4_reducepool = 128,name = 'inception5a')
    #inception5b
    x = inceptionA(x = x,f_branch1_1x1 = 352,f_branch2_reduce3 = 192,f_branch2_3x3 = 320,f_branch3_reducedb3 = 192,f_branch3_db3 = [224, 224],f_branch4_reducepool = 128,name = 'inception5b')
    
    #global avg pooling
    x = keras.layers.GlobalAveragePooling2D(name = 'global_average_pooling')(x)#1x1x1024
    if use_dropout:
        x = keras.layers.Dropout(dropout_rate, name = 'dropout')(x)
    
    x = keras.layers.Dense(classes, activation = 'softmax', name = 'classification')(x)
    model = keras.models.Model(inputs = x_input, outputs = x, name = 'inceptionv2')
    return model

# %%
model = inceptionv2()
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9408        input_19[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_conv (Conv2D)             (None, 56, 56, 192)  110592      pool1[0][0]
# __________________________________________________________________________________________________
# conv2_bn (BatchNormalization)   (None, 56, 56, 192)  768         conv2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_relu (Activation)         (None, 56, 56, 192)  0           conv2_bn[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 28, 28, 192)  0           conv2_relu[0][0]
# __________________________________________________________________________________________________
# inception3a_branch3_conv1x1_con (None, 28, 28, 64)   12288       pool2[0][0]
# __________________________________________________________________________________________________
# inception3a_branch3_conv1x1_bn  (None, 28, 28, 64)   256         inception3a_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3a_branch3_conv1x1_rel (None, 28, 28, 64)   0           inception3a_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3a_branch2_conv1x1_con (None, 28, 28, 64)   12288       pool2[0][0]
# __________________________________________________________________________________________________
# inception3a_branch3_conv3x3_1_c (None, 28, 28, 96)   55296       inception3a_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3a_branch2_conv1x1_bn  (None, 28, 28, 64)   256         inception3a_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3a_branch3_conv3x3_1_b (None, 28, 28, 96)   384         inception3a_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception3a_branch2_conv1x1_rel (None, 28, 28, 64)   0           inception3a_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3a_branch3_conv3x3_1_r (None, 28, 28, 96)   0           inception3a_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception3a_branch4_pool (Avera (None, 28, 28, 192)  0           pool2[0][0]
# __________________________________________________________________________________________________
# inception3a_branch1_conv1x1_con (None, 28, 28, 64)   12288       pool2[0][0]
# __________________________________________________________________________________________________
# inception3a_branch2_conv3x3_con (None, 28, 28, 64)   36864       inception3a_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3a_branch3_conv3x3_2_c (None, 28, 28, 96)   82944       inception3a_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception3a_branch4_conv1x1_con (None, 28, 28, 32)   6144        inception3a_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception3a_branch1_conv1x1_bn  (None, 28, 28, 64)   256         inception3a_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3a_branch2_conv3x3_bn  (None, 28, 28, 64)   256         inception3a_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception3a_branch3_conv3x3_2_b (None, 28, 28, 96)   384         inception3a_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception3a_branch4_conv1x1_bn  (None, 28, 28, 32)   128         inception3a_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3a_branch1_conv1x1_rel (None, 28, 28, 64)   0           inception3a_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3a_branch2_conv3x3_rel (None, 28, 28, 64)   0           inception3a_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception3a_branch3_conv3x3_2_r (None, 28, 28, 96)   0           inception3a_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception3a_branch4_conv1x1_rel (None, 28, 28, 32)   0           inception3a_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3a (Concatenate)       (None, 28, 28, 256)  0           inception3a_branch1_conv1x1_relu[
#                                                                  inception3a_branch2_conv3x3_relu[
#                                                                  inception3a_branch3_conv3x3_2_rel
#                                                                  inception3a_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3b_branch3_conv1x1_con (None, 28, 28, 64)   16384       inception3a[0][0]
# __________________________________________________________________________________________________
# inception3b_branch3_conv1x1_bn  (None, 28, 28, 64)   256         inception3b_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3b_branch3_conv1x1_rel (None, 28, 28, 64)   0           inception3b_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3b_branch2_conv1x1_con (None, 28, 28, 64)   16384       inception3a[0][0]
# __________________________________________________________________________________________________
# inception3b_branch3_conv3x3_1_c (None, 28, 28, 96)   55296       inception3b_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3b_branch2_conv1x1_bn  (None, 28, 28, 64)   256         inception3b_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3b_branch3_conv3x3_1_b (None, 28, 28, 96)   384         inception3b_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception3b_branch2_conv1x1_rel (None, 28, 28, 64)   0           inception3b_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3b_branch3_conv3x3_1_r (None, 28, 28, 96)   0           inception3b_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception3b_branch4_pool (Avera (None, 28, 28, 256)  0           inception3a[0][0]
# __________________________________________________________________________________________________
# inception3b_branch1_conv1x1_con (None, 28, 28, 64)   16384       inception3a[0][0]
# __________________________________________________________________________________________________
# inception3b_branch2_conv3x3_con (None, 28, 28, 96)   55296       inception3b_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3b_branch3_conv3x3_2_c (None, 28, 28, 96)   82944       inception3b_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception3b_branch4_conv1x1_con (None, 28, 28, 64)   16384       inception3b_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception3b_branch1_conv1x1_bn  (None, 28, 28, 64)   256         inception3b_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3b_branch2_conv3x3_bn  (None, 28, 28, 96)   384         inception3b_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception3b_branch3_conv3x3_2_b (None, 28, 28, 96)   384         inception3b_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception3b_branch4_conv1x1_bn  (None, 28, 28, 64)   256         inception3b_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3b_branch1_conv1x1_rel (None, 28, 28, 64)   0           inception3b_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3b_branch2_conv3x3_rel (None, 28, 28, 96)   0           inception3b_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception3b_branch3_conv3x3_2_r (None, 28, 28, 96)   0           inception3b_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception3b_branch4_conv1x1_rel (None, 28, 28, 64)   0           inception3b_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3b (Concatenate)       (None, 28, 28, 320)  0           inception3b_branch1_conv1x1_relu[
#                                                                  inception3b_branch2_conv3x3_relu[
#                                                                  inception3b_branch3_conv3x3_2_rel
#                                                                  inception3b_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3c_branch2_conv1x1_con (None, 28, 28, 64)   20480       inception3b[0][0]
# __________________________________________________________________________________________________
# inception3c_branch2_conv1x1_bn  (None, 28, 28, 64)   256         inception3c_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3c_branch2_conv1x1_rel (None, 28, 28, 64)   0           inception3c_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3c_branch1_conv1x1_con (None, 28, 28, 128)  40960       inception3b[0][0]
# __________________________________________________________________________________________________
# inception3c_branch2_conv3x3_1_c (None, 28, 28, 96)   55296       inception3c_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3c_branch1_conv1x1_bn  (None, 28, 28, 128)  512         inception3c_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception3c_branch2_conv3x3_1_b (None, 28, 28, 96)   384         inception3c_branch2_conv3x3_1_con
# __________________________________________________________________________________________________
# inception3c_branch1_conv1x1_rel (None, 28, 28, 128)  0           inception3c_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception3c_branch2_conv3x3_1_r (None, 28, 28, 96)   0           inception3c_branch2_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception3c_branch1_conv3x3_con (None, 14, 14, 160)  184320      inception3c_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# inception3c_branch2_conv3x3_2_c (None, 14, 14, 96)   82944       inception3c_branch2_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception3c_branch1_conv3x3_bn  (None, 14, 14, 160)  640         inception3c_branch1_conv3x3_conv[
# __________________________________________________________________________________________________
# inception3c_branch2_conv3x3_2_b (None, 14, 14, 96)   384         inception3c_branch2_conv3x3_2_con
# __________________________________________________________________________________________________
# inception3c_branch1_conv3x3_rel (None, 14, 14, 160)  0           inception3c_branch1_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception3c_branch2_conv3x3_2_r (None, 14, 14, 96)   0           inception3c_branch2_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception3c_branch3_pool (MaxPo (None, 14, 14, 320)  0           inception3b[0][0]
# __________________________________________________________________________________________________
# inception3c (Concatenate)       (None, 14, 14, 576)  0           inception3c_branch1_conv3x3_relu[
#                                                                  inception3c_branch2_conv3x3_2_rel
#                                                                  inception3c_branch3_pool[0][0]
# __________________________________________________________________________________________________
# inception4a_branch3_conv1x1_con (None, 14, 14, 96)   55296       inception3c[0][0]
# __________________________________________________________________________________________________
# inception4a_branch3_conv1x1_bn  (None, 14, 14, 96)   384         inception4a_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4a_branch3_conv1x1_rel (None, 14, 14, 96)   0           inception4a_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4a_branch2_conv1x1_con (None, 14, 14, 64)   36864       inception3c[0][0]
# __________________________________________________________________________________________________
# inception4a_branch3_conv3x3_1_c (None, 14, 14, 128)  110592      inception4a_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4a_branch2_conv1x1_bn  (None, 14, 14, 64)   256         inception4a_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4a_branch3_conv3x3_1_b (None, 14, 14, 128)  512         inception4a_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception4a_branch2_conv1x1_rel (None, 14, 14, 64)   0           inception4a_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4a_branch3_conv3x3_1_r (None, 14, 14, 128)  0           inception4a_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception4a_branch4_pool (Avera (None, 14, 14, 576)  0           inception3c[0][0]
# __________________________________________________________________________________________________
# inception4a_branch1_conv1x1_con (None, 14, 14, 224)  129024      inception3c[0][0]
# __________________________________________________________________________________________________
# inception4a_branch2_conv3x3_con (None, 14, 14, 96)   55296       inception4a_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4a_branch3_conv3x3_2_c (None, 14, 14, 128)  147456      inception4a_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception4a_branch4_conv1x1_con (None, 14, 14, 128)  73728       inception4a_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception4a_branch1_conv1x1_bn  (None, 14, 14, 224)  896         inception4a_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4a_branch2_conv3x3_bn  (None, 14, 14, 96)   384         inception4a_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception4a_branch3_conv3x3_2_b (None, 14, 14, 128)  512         inception4a_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception4a_branch4_conv1x1_bn  (None, 14, 14, 128)  512         inception4a_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4a_branch1_conv1x1_rel (None, 14, 14, 224)  0           inception4a_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4a_branch2_conv3x3_rel (None, 14, 14, 96)   0           inception4a_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception4a_branch3_conv3x3_2_r (None, 14, 14, 128)  0           inception4a_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception4a_branch4_conv1x1_rel (None, 14, 14, 128)  0           inception4a_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4a (Concatenate)       (None, 14, 14, 576)  0           inception4a_branch1_conv1x1_relu[
#                                                                  inception4a_branch2_conv3x3_relu[
#                                                                  inception4a_branch3_conv3x3_2_rel
#                                                                  inception4a_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4b_branch3_conv1x1_con (None, 14, 14, 96)   55296       inception4a[0][0]
# __________________________________________________________________________________________________
# inception4b_branch3_conv1x1_bn  (None, 14, 14, 96)   384         inception4b_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4b_branch3_conv1x1_rel (None, 14, 14, 96)   0           inception4b_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4b_branch2_conv1x1_con (None, 14, 14, 96)   55296       inception4a[0][0]
# __________________________________________________________________________________________________
# inception4b_branch3_conv3x3_1_c (None, 14, 14, 128)  110592      inception4b_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4b_branch2_conv1x1_bn  (None, 14, 14, 96)   384         inception4b_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4b_branch3_conv3x3_1_b (None, 14, 14, 128)  512         inception4b_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception4b_branch2_conv1x1_rel (None, 14, 14, 96)   0           inception4b_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4b_branch3_conv3x3_1_r (None, 14, 14, 128)  0           inception4b_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception4b_branch4_pool (Avera (None, 14, 14, 576)  0           inception4a[0][0]
# __________________________________________________________________________________________________
# inception4b_branch1_conv1x1_con (None, 14, 14, 192)  110592      inception4a[0][0]
# __________________________________________________________________________________________________
# inception4b_branch2_conv3x3_con (None, 14, 14, 128)  110592      inception4b_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4b_branch3_conv3x3_2_c (None, 14, 14, 128)  147456      inception4b_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception4b_branch4_conv1x1_con (None, 14, 14, 128)  73728       inception4b_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception4b_branch1_conv1x1_bn  (None, 14, 14, 192)  768         inception4b_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4b_branch2_conv3x3_bn  (None, 14, 14, 128)  512         inception4b_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception4b_branch3_conv3x3_2_b (None, 14, 14, 128)  512         inception4b_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception4b_branch4_conv1x1_bn  (None, 14, 14, 128)  512         inception4b_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4b_branch1_conv1x1_rel (None, 14, 14, 192)  0           inception4b_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4b_branch2_conv3x3_rel (None, 14, 14, 128)  0           inception4b_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception4b_branch3_conv3x3_2_r (None, 14, 14, 128)  0           inception4b_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception4b_branch4_conv1x1_rel (None, 14, 14, 128)  0           inception4b_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4b (Concatenate)       (None, 14, 14, 576)  0           inception4b_branch1_conv1x1_relu[
#                                                                  inception4b_branch2_conv3x3_relu[
#                                                                  inception4b_branch3_conv3x3_2_rel
#                                                                  inception4b_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4c_branch3_conv1x1_con (None, 14, 14, 128)  73728       inception4b[0][0]
# __________________________________________________________________________________________________
# inception4c_branch3_conv1x1_bn  (None, 14, 14, 128)  512         inception4c_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4c_branch3_conv1x1_rel (None, 14, 14, 128)  0           inception4c_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4c_branch2_conv1x1_con (None, 14, 14, 128)  73728       inception4b[0][0]
# __________________________________________________________________________________________________
# inception4c_branch3_conv3x3_1_c (None, 14, 14, 160)  184320      inception4c_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4c_branch2_conv1x1_bn  (None, 14, 14, 128)  512         inception4c_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4c_branch3_conv3x3_1_b (None, 14, 14, 160)  640         inception4c_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception4c_branch2_conv1x1_rel (None, 14, 14, 128)  0           inception4c_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4c_branch3_conv3x3_1_r (None, 14, 14, 160)  0           inception4c_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception4c_branch4_pool (Avera (None, 14, 14, 576)  0           inception4b[0][0]
# __________________________________________________________________________________________________
# inception4c_branch1_conv1x1_con (None, 14, 14, 160)  92160       inception4b[0][0]
# __________________________________________________________________________________________________
# inception4c_branch2_conv3x3_con (None, 14, 14, 160)  184320      inception4c_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4c_branch3_conv3x3_2_c (None, 14, 14, 160)  230400      inception4c_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception4c_branch4_conv1x1_con (None, 14, 14, 96)   55296       inception4c_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception4c_branch1_conv1x1_bn  (None, 14, 14, 160)  640         inception4c_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4c_branch2_conv3x3_bn  (None, 14, 14, 160)  640         inception4c_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception4c_branch3_conv3x3_2_b (None, 14, 14, 160)  640         inception4c_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception4c_branch4_conv1x1_bn  (None, 14, 14, 96)   384         inception4c_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4c_branch1_conv1x1_rel (None, 14, 14, 160)  0           inception4c_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4c_branch2_conv3x3_rel (None, 14, 14, 160)  0           inception4c_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception4c_branch3_conv3x3_2_r (None, 14, 14, 160)  0           inception4c_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception4c_branch4_conv1x1_rel (None, 14, 14, 96)   0           inception4c_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4c (Concatenate)       (None, 14, 14, 576)  0           inception4c_branch1_conv1x1_relu[
#                                                                  inception4c_branch2_conv3x3_relu[
#                                                                  inception4c_branch3_conv3x3_2_rel
#                                                                  inception4c_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4d_branch3_conv1x1_con (None, 14, 14, 160)  92160       inception4c[0][0]
# __________________________________________________________________________________________________
# inception4d_branch3_conv1x1_bn  (None, 14, 14, 160)  640         inception4d_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4d_branch3_conv1x1_rel (None, 14, 14, 160)  0           inception4d_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4d_branch2_conv1x1_con (None, 14, 14, 128)  73728       inception4c[0][0]
# __________________________________________________________________________________________________
# inception4d_branch3_conv3x3_1_c (None, 14, 14, 192)  276480      inception4d_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4d_branch2_conv1x1_bn  (None, 14, 14, 128)  512         inception4d_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4d_branch3_conv3x3_1_b (None, 14, 14, 192)  768         inception4d_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception4d_branch2_conv1x1_rel (None, 14, 14, 128)  0           inception4d_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4d_branch3_conv3x3_1_r (None, 14, 14, 192)  0           inception4d_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception4d_branch4_pool (Avera (None, 14, 14, 576)  0           inception4c[0][0]
# __________________________________________________________________________________________________
# inception4d_branch1_conv1x1_con (None, 14, 14, 96)   55296       inception4c[0][0]
# __________________________________________________________________________________________________
# inception4d_branch2_conv3x3_con (None, 14, 14, 192)  221184      inception4d_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4d_branch3_conv3x3_2_c (None, 14, 14, 192)  331776      inception4d_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception4d_branch4_conv1x1_con (None, 14, 14, 96)   55296       inception4d_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception4d_branch1_conv1x1_bn  (None, 14, 14, 96)   384         inception4d_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4d_branch2_conv3x3_bn  (None, 14, 14, 192)  768         inception4d_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception4d_branch3_conv3x3_2_b (None, 14, 14, 192)  768         inception4d_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception4d_branch4_conv1x1_bn  (None, 14, 14, 96)   384         inception4d_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4d_branch1_conv1x1_rel (None, 14, 14, 96)   0           inception4d_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4d_branch2_conv3x3_rel (None, 14, 14, 192)  0           inception4d_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception4d_branch3_conv3x3_2_r (None, 14, 14, 192)  0           inception4d_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception4d_branch4_conv1x1_rel (None, 14, 14, 96)   0           inception4d_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4d (Concatenate)       (None, 14, 14, 576)  0           inception4d_branch1_conv1x1_relu[
#                                                                  inception4d_branch2_conv3x3_relu[
#                                                                  inception4d_branch3_conv3x3_2_rel
#                                                                  inception4d_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4e_branch2_conv1x1_con (None, 14, 14, 192)  110592      inception4d[0][0]
# __________________________________________________________________________________________________
# inception4e_branch2_conv1x1_bn  (None, 14, 14, 192)  768         inception4e_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4e_branch2_conv1x1_rel (None, 14, 14, 192)  0           inception4e_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4e_branch1_conv1x1_con (None, 14, 14, 128)  73728       inception4d[0][0]
# __________________________________________________________________________________________________
# inception4e_branch2_conv3x3_1_c (None, 14, 14, 256)  442368      inception4e_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4e_branch1_conv1x1_bn  (None, 14, 14, 128)  512         inception4e_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception4e_branch2_conv3x3_1_b (None, 14, 14, 256)  1024        inception4e_branch2_conv3x3_1_con
# __________________________________________________________________________________________________
# inception4e_branch1_conv1x1_rel (None, 14, 14, 128)  0           inception4e_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception4e_branch2_conv3x3_1_r (None, 14, 14, 256)  0           inception4e_branch2_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception4e_branch1_conv3x3_con (None, 7, 7, 192)    221184      inception4e_branch1_conv1x1_relu[
# __________________________________________________________________________________________________
# inception4e_branch2_conv3x3_2_c (None, 7, 7, 256)    589824      inception4e_branch2_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception4e_branch1_conv3x3_bn  (None, 7, 7, 192)    768         inception4e_branch1_conv3x3_conv[
# __________________________________________________________________________________________________
# inception4e_branch2_conv3x3_2_b (None, 7, 7, 256)    1024        inception4e_branch2_conv3x3_2_con
# __________________________________________________________________________________________________
# inception4e_branch1_conv3x3_rel (None, 7, 7, 192)    0           inception4e_branch1_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception4e_branch2_conv3x3_2_r (None, 7, 7, 256)    0           inception4e_branch2_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception4e_branch3_pool (MaxPo (None, 7, 7, 576)    0           inception4d[0][0]
# __________________________________________________________________________________________________
# inception4e (Concatenate)       (None, 7, 7, 1024)   0           inception4e_branch1_conv3x3_relu[
#                                                                  inception4e_branch2_conv3x3_2_rel
#                                                                  inception4e_branch3_pool[0][0]
# __________________________________________________________________________________________________
# inception5a_branch3_conv1x1_con (None, 7, 7, 160)    163840      inception4e[0][0]
# __________________________________________________________________________________________________
# inception5a_branch3_conv1x1_bn  (None, 7, 7, 160)    640         inception5a_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5a_branch3_conv1x1_rel (None, 7, 7, 160)    0           inception5a_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5a_branch2_conv1x1_con (None, 7, 7, 192)    196608      inception4e[0][0]
# __________________________________________________________________________________________________
# inception5a_branch3_conv3x3_1_c (None, 7, 7, 224)    322560      inception5a_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception5a_branch2_conv1x1_bn  (None, 7, 7, 192)    768         inception5a_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5a_branch3_conv3x3_1_b (None, 7, 7, 224)    896         inception5a_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception5a_branch2_conv1x1_rel (None, 7, 7, 192)    0           inception5a_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5a_branch3_conv3x3_1_r (None, 7, 7, 224)    0           inception5a_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception5a_branch4_pool (Avera (None, 7, 7, 1024)   0           inception4e[0][0]
# __________________________________________________________________________________________________
# inception5a_branch1_conv1x1_con (None, 7, 7, 352)    360448      inception4e[0][0]
# __________________________________________________________________________________________________
# inception5a_branch2_conv3x3_con (None, 7, 7, 320)    552960      inception5a_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception5a_branch3_conv3x3_2_c (None, 7, 7, 224)    451584      inception5a_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception5a_branch4_conv1x1_con (None, 7, 7, 128)    131072      inception5a_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception5a_branch1_conv1x1_bn  (None, 7, 7, 352)    1408        inception5a_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5a_branch2_conv3x3_bn  (None, 7, 7, 320)    1280        inception5a_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception5a_branch3_conv3x3_2_b (None, 7, 7, 224)    896         inception5a_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception5a_branch4_conv1x1_bn  (None, 7, 7, 128)    512         inception5a_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5a_branch1_conv1x1_rel (None, 7, 7, 352)    0           inception5a_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5a_branch2_conv3x3_rel (None, 7, 7, 320)    0           inception5a_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception5a_branch3_conv3x3_2_r (None, 7, 7, 224)    0           inception5a_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception5a_branch4_conv1x1_rel (None, 7, 7, 128)    0           inception5a_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5a (Concatenate)       (None, 7, 7, 1024)   0           inception5a_branch1_conv1x1_relu[
#                                                                  inception5a_branch2_conv3x3_relu[
#                                                                  inception5a_branch3_conv3x3_2_rel
#                                                                  inception5a_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# inception5b_branch3_conv1x1_con (None, 7, 7, 192)    196608      inception5a[0][0]
# __________________________________________________________________________________________________
# inception5b_branch3_conv1x1_bn  (None, 7, 7, 192)    768         inception5b_branch3_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5b_branch3_conv1x1_rel (None, 7, 7, 192)    0           inception5b_branch3_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5b_branch2_conv1x1_con (None, 7, 7, 192)    196608      inception5a[0][0]
# __________________________________________________________________________________________________
# inception5b_branch3_conv3x3_1_c (None, 7, 7, 224)    387072      inception5b_branch3_conv1x1_relu[
# __________________________________________________________________________________________________
# inception5b_branch2_conv1x1_bn  (None, 7, 7, 192)    768         inception5b_branch2_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5b_branch3_conv3x3_1_b (None, 7, 7, 224)    896         inception5b_branch3_conv3x3_1_con
# __________________________________________________________________________________________________
# inception5b_branch2_conv1x1_rel (None, 7, 7, 192)    0           inception5b_branch2_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5b_branch3_conv3x3_1_r (None, 7, 7, 224)    0           inception5b_branch3_conv3x3_1_bn[
# __________________________________________________________________________________________________
# inception5b_branch4_pool (Avera (None, 7, 7, 1024)   0           inception5a[0][0]
# __________________________________________________________________________________________________
# inception5b_branch1_conv1x1_con (None, 7, 7, 352)    360448      inception5a[0][0]
# __________________________________________________________________________________________________
# inception5b_branch2_conv3x3_con (None, 7, 7, 320)    552960      inception5b_branch2_conv1x1_relu[
# __________________________________________________________________________________________________
# inception5b_branch3_conv3x3_2_c (None, 7, 7, 224)    451584      inception5b_branch3_conv3x3_1_rel
# __________________________________________________________________________________________________
# inception5b_branch4_conv1x1_con (None, 7, 7, 128)    131072      inception5b_branch4_pool[0][0]
# __________________________________________________________________________________________________
# inception5b_branch1_conv1x1_bn  (None, 7, 7, 352)    1408        inception5b_branch1_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5b_branch2_conv3x3_bn  (None, 7, 7, 320)    1280        inception5b_branch2_conv3x3_conv[
# __________________________________________________________________________________________________
# inception5b_branch3_conv3x3_2_b (None, 7, 7, 224)    896         inception5b_branch3_conv3x3_2_con
# __________________________________________________________________________________________________
# inception5b_branch4_conv1x1_bn  (None, 7, 7, 128)    512         inception5b_branch4_conv1x1_conv[
# __________________________________________________________________________________________________
# inception5b_branch1_conv1x1_rel (None, 7, 7, 352)    0           inception5b_branch1_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5b_branch2_conv3x3_rel (None, 7, 7, 320)    0           inception5b_branch2_conv3x3_bn[0]
# __________________________________________________________________________________________________
# inception5b_branch3_conv3x3_2_r (None, 7, 7, 224)    0           inception5b_branch3_conv3x3_2_bn[
# __________________________________________________________________________________________________
# inception5b_branch4_conv1x1_rel (None, 7, 7, 128)    0           inception5b_branch4_conv1x1_bn[0]
# __________________________________________________________________________________________________
# inception5b (Concatenate)       (None, 7, 7, 1024)   0           inception5b_branch1_conv1x1_relu[
#                                                                  inception5b_branch2_conv3x3_relu[
#                                                                  inception5b_branch3_conv3x3_2_rel
#                                                                  inception5b_branch4_conv1x1_relu[
# __________________________________________________________________________________________________
# global_average_pooling (GlobalA (None, 1024)         0           inception5b[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           global_average_pooling[0][0]
# __________________________________________________________________________________________________
# classification (Dense)          (None, 1000)         1025000     dropout[0][0]
# ==================================================================================================
# Total params: 11,210,536
# Trainable params: 11,190,760
# Non-trainable params: 19,776
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## 参考文献
# (1) Ioffe S, Szegedy C. Batch normalization: Accelerating deep network training by reducing internal covariate shift[J]. arXiv preprint arXiv:1502.03167, 2015.
